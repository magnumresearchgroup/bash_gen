# %% [markdown]
# # 'Find' Syntax Structure Examples
#
# In this notebook, we will be exploring different syntax representations for the 'find' bash command to help improve the generator, particularly its ability to generate valid 'find' commands, with the hope being we can also apply these techniques to all of the other commands.
#
# To do this, we will be going through our entire pipeline and optimizing for efficiency and correctness at every step.

# %%
from generator import *
import json

# %% [markdown]
# ## Exploring Known Find Commands
#
# From the training data, parsing a list of all the find commands to see examples of what proper syntax structure looks like for the find command

# %%
with open('cmds_proccess_train.txt') as fp:
    txt = fp.read()
    
find_cmds = []
for cmd in txt.split('\n'):
    if cmd.split(" ")[0] == "find":
        find_cmds.append(cmd)
        
find_cmds[:20]
# Out:
# ['find Path -type d ! -perm -Permission',
#  'find Path -type d -name Regex -execdir tar -c -v -f File File \\;',
#  'find Path -user Regex',
#  'find Path -name Regex -delete',
#  'find Path -name Regex',
#  'find Path -group Regex',
#  'find Path -type d -exec chmod Permission {} +',
#  'find Path -type f -print0 | xargs -r -0 -I {} grep -F Regex {}',
#  'find Path -name Regex | xargs -I {} grep -r Regex {}',
#  'find Path Path Path Path',
#  'find Path -type f -name Regex',
#  'find Path -print0 | xargs -0 -I {} echo {}',
#  'find Path -type d -name Regex -exec rsync -a -v -R {} File \\; -exec rm -r -f File \\;',
#  'find Path -mmin -Quantity',
#  'find Path -type f -exec bzip2 {} \\;',
#  'find Path -name Regex -type f -exec wc -l File \\;',
#  'find Path -type c',
#  'find Path -name Regex -prune -or -print',
#  'find Path -nouser -exec rm File \\;',
#  'find Path -name Regex -exec grep Regex {} \\;']

# %% [markdown]
# Clearly, the syntax structure is different than the initial thought which is likely to have caused a lot of the problems. The initial syntax structure was 'find options Folder Regex' when it's clear that the Folder (or path) comes before the options, and that the Regex is not mandatory, but instead comes as a result of the options.
#
# So, I have switched the syntax structure to 'find Folder options' and let's keep moving forward.
#
# ## Scraping of Find Command Arguments

# %%
from scraper import WebScraper

ws = WebScraper(utilities=['find'])
ws.extract_utilities()
ws.save_json(map_path='find_scrape.json')
# Out:
# find
# syntax not found for find
# /Users/mgeorgaklis/Desktop/Fall 2021 Coursework/CS 3860/bash_gen/scraper.py:32: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 32 of the file /Users/mgeorgaklis/Desktop/Fall 2021 Coursework/CS 3860/bash_gen/scraper.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   soup = BeautifulSoup(r.text)

# %%
ws.non_conforming_flags()
# Out:
# ['find:-D:debugopts',
#  'find:-type:c',
#  'find:-printf:format',
#  'find:-xtype:c',
#  'find:-fstype:type',
#  'find:-perm:+mode',
#  'find:-regextype:type',
#  'find:-mindepth:levels',
#  'find:-not:expr',
#  'find:-maxdepth:levels',
#  'find -L:-D:debugopts',
#  'find -L:-type:c',
#  'find -L:-printf:format',
#  'find -L:-xtype:c',
#  'find -L:-fstype:type',
#  'find -L:-perm:+mode',
#  'find -L:-regextype:type',
#  'find -L:-mindepth:levels',
#  'find -L:-not:expr',
#  'find -L:-maxdepth:levels']

# %% [markdown]
# ## Generation of Find Commands
#
# Now that the syntax is switched, the commands look like the following.

# %%
find_gen = Generator(map_path='find_scrape.json', utilities=["find"])

# %%
find_cmds = find_gen.generate_all_commands()
find_cmds[:10]
# Out:
# ['find Folder -mmin Number -L -or',
#  'find Folder -execdir -nogroup -user Number',
#  'find Folder -fprint0 File -print0 -O',
#  'find Folder -daystart -executable -empty',
#  'find Folder -wholename Regex -follow -print0',
#  'find Folder -ok -d -ctime Number',
#  'find Folder -fprint File -empty -mount',
#  'find Folder -path Regex -Olevel -true',
#  'find Folder -L -okdir -xdev',
#  'find Folder -ok -ilname Regex -size Number']

# %%
len(find_cmds)
# Out:
# 64823

# %% [markdown]
# It looks like we were able to generate over 64,000 find commands

# %%
with open('generic_find_cmds.txt', 'w') as fp:
    fp.write("\n".join(find_cmds))

# %% [markdown]
# ## Replacement of Arguments in Generic Commands.

# %%
replace(rep_path='find_replacement_map.json', in_path='generic_find_cmds.txt', out_path='replaced_find_cmds_2.txt')

# %%
with open('replaced_find_cmds_2.txt') as fp:
    cmds = fp.read().split("\n")
cmds[:10]
# Out:
# ['find . -fprint temp.txt -d',
#  'find . -links 1 -noignore_readdir_race',
#  "find . -exec -ipath '*txt' -lname '*txt'",
#  'find . -readable -fprint temp.txt -false',
#  "find . -d -ilname '*txt'",
#  "find . -newer 1 -okdir -ilname '*txt'",
#  'find . -o -d -noignore_readdir_race',
#  'find . -mount -user 1 -mtime 1',
#  "find . -xdev -context '*txt' -ctime 1",
#  "find . -H -false -ilname '*txt'"]

# %% [markdown]
# ## Validation of the find commands
#
# Our generator includes the "validate_commands()" function which runs all of the generated commands in a particular file at the command line, and determines whether they are valid based on the exit status returned. It's important that the validation aspect is working correctly, so that we can maximize the number of actual valid commands we can return.
#
# Here we will be running some of our generated commands through the validation pipeline and observing how they perform.

# %%
import subprocess

subprocess.check_output(cmds[1], shell=True)
# Out:
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-30-f0f1c9bd5d6c> in <module>
#       1 import subprocess
#       2
# ----> 3 subprocess.check_output(cmds[1], shell=True)
#
# /opt/anaconda3/lib/python3.8/subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     409         kwargs['input'] = '' if kwargs.get('universal_newlines', False) else b''
#     410
# --> 411     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#     412                **kwargs).stdout
#     413
#
# /opt/anaconda3/lib/python3.8/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     510         retcode = process.poll()
#     511         if check and retcode:
# --> 512             raise CalledProcessError(retcode, process.args,
#     513                                      output=stdout, stderr=stderr)
#     514     return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command 'find . -print -H -xdevs' returned non-zero exit status 1.

# %%
with open('verified_find2.txt') as fp:
    txt = fp.read()
    
txt = txt.split('\n')
len(txt)
# Out:
# 25491

# %%
def make_generic(rep_path, in_file, out_file):
    with open(rep_path, 'r') as fp:
        reps = json.load(fp)
    
    d = {}
    for k in reps:
        d[reps[k]] = k
        
    with open(in_file) as fp:
        cmds = fp.read().split('\n')
    
    ret = []
    for cmd in cmds:
        ret_cmd = []
        lst = cmd.split(" ")
        for val in lst:
            if val in d:
                val = d[val]
            ret_cmd.append(val)
        ret.append(" ".join(ret_cmd))
    
    with open(out_file, 'w') as fp:
        fp.write("\n".join(ret))

# %%
make_generic('find_replacement_map.json', 'verified_find2.txt', 'verified_generic_find_cmds2.txt')

# %%
ret = []
with open('verified_generic_find_cmds2.txt') as fp:
    cmds = fp.read().split('\n')
    for cmd in cmds:
        cmd = cmd.replace("Folder", "Path")
        ret.append(cmd)
ret = "\n".join(ret)

with open('verified_generic_find_cmds2.txt', 'w') as fp:
    fp.write(ret)

# %%
with open('generic_training.txt') as fp:
    txt = fp.read()

# %%
ret = []
for cmd in txt.split('\n'):
    ret.append(cmd.replace('Directory', 'Path'))
ret
# Out:
# ['find Path -print -nouser -help',
#  'find Path -inum Timespan -samefile File -xdev',
#  'find Path -used Timespan -fprint0 File -xdev',
#  'find Path -ls -noignore_readdir_race -size Timespan',
#  'find Path -depth -used Timespan -ilname Regex',
#  'find Path -version -lname Regex -empty',
#  'find Path -version -depth -samefile File',
#  'find Path -readable -inum Timespan -group Timespan',
#  'find Path -fls File -cmin Timespan -true',
#  'find Path -print -nouser -samefile File',
#  'find Path -ls -fprint0 File -amin Timespan',
#  'find Path -version -inum Timespan -wholename Regex',
#  'find Path -ignore_readdir_race -false',
#  'find Path -nogroup -executable -fprint0 File',
#  'find Path -name Regex -ctime Timespan -atime Timespan',
#  'find Path -mtime Timespan -delete -print0',
#  'find Path -ignore_readdir_race -ilname Regex -size Timespan',
#  'find Path -iregex Regex -inum Timespan -ctime Timespan',
#  'find Path -print -empty -executable',
#  'find Path -print -quit -mmin Timespan',
#  'find Path -version -depth -ilname Regex',
#  'find Path -group Timespan -user Timespan -path Regex',
#  'find Path -group Timespan -ilname Regex',
#  'find Path -fls File -daystart -ignore_readdir_race',
#  'find Path -iregex Regex -warn -fprint0 File',
#  'find Path -fprintf -user Timespan -fprint File',
#  'find Path -ilname Regex -path Regex -xdev',
#  'find Path -mtime Timespan -samefile File -false',
#  'find Path -nouser -fls File -prune',
#  'find Path -readable -ilname Regex -fprint0 File',
#  'find Path -name Regex -atime Timespan -true',
#  'find Path -iregex Regex -warn -executable',
#  'find Path -ipath Regex -noignore_readdir_race -used Timespan',
#  'find Path -delete -regex Regex -fprint File',
#  'find Path -inum Timespan -regex Regex -false',
#  'find Path -readable -mtime Timespan -lname Regex',
#  'find Path -iwholename Regex -depth -ctime Timespan',
#  'find Path -iregex Regex -regex Regex -path Regex',
#  'find Path -wholename Regex -help -O',
#  'find Path -iwholename Regex -inum Timespan -used Timespan',
#  'find Path -used Timespan -samefile File -false',
#  'find Path -fls File -mount -path Regex',
#  'find Path -ignore_readdir_race -executable -fprint0 File',
#  'find Path -fprintf -user Timespan',
#  'find Path -lname Regex -noleaf -true',
#  'find Path -readable -fprint0 File -path Regex',
#  'find Path -ctime Timespan -warn -cmin Timespan',
#  'find Path -daystart -amin Timespan',
#  'find Path -links Timespan -user Timespan -path Regex',
#  'find Path -iname Regex -ignore_readdir_race -empty',
#  'find Path -ctime Timespan -wholename Regex -help',
#  'find Path -version -help -xdev',
#  'find Path -or -d -help',
#  'find Path -mtime Timespan -noignore_readdir_race -samefile File',
#  'find Path -ls -name Regex -iwholename Regex',
#  'find Path -lname Regex -help -context Regex',
#  'find Path -print -or -ctime Timespan',
#  'find Path -ignore_readdir_race -atime Timespan -size Timespan',
#  'find Path -noleaf -used Timespan -follow',
#  'find Path -readable -mmin Timespan -empty',
#  'find Path -print -executable -follow',
#  'find Path -nogroup -lname Regex -help',
#  'find Path -ls -readable -xdev',
#  'find Path -version -exec -executable',
#  'find Path -readable -d -ignore_readdir_race',
#  'find Path -noleaf -false -follow',
#  'find Path -fls File -daystart -xdev',
#  'find Path -name Regex -fprintf -cmin Timespan',
#  'find Path -iwholename Regex -mmin Timespan -group Timespan',
#  'find Path -lname Regex -noleaf -executable',
#  'find Path -prune -atime Timespan -user Timespan',
#  'find Path -fls File -mount -user Timespan',
#  'find Path -noignore_readdir_race -ignore_readdir_race -user Timespan',
#  'find Path -inum Timespan -used Timespan -group Timespan',
#  'find Path -iname Regex -wholename Regex -help',
#  'find Path -readable -atime Timespan -fprint File',
#  'find Path -links Timespan -mmin Timespan -executable',
#  'find Path -links Timespan -ilname Regex -amin Timespan',
#  'find Path -iname Regex -regex Regex -warn',
#  'find Path -print -noleaf -mmin Timespan',
#  'find Path -version -mount -fprint0 File',
#  'find Path -print -readable -ilname Regex',
#  'find Path -warn -user Timespan -print0',
#  'find Path -iregex Regex -regex Regex -follow',
#  'find Path -ipath Regex -daystart -lname Regex',
#  'find Path -prune -d -atime Timespan',
#  'find Path -regex Regex -used Timespan -follow',
#  'find Path -ipath Regex -warn',
#  'find Path -fls File -noleaf -executable',
#  'find Path -iwholename Regex -user Timespan -follow',
#  'find Path -nogroup -version -atime Timespan',
#  'find Path -version -daystart -fprintf',
#  'find Path -noignore_readdir_race -help -ilname Regex',
#  'find Path -print -ignore_readdir_race -fprint0 File',
#  'find Path -nogroup -help -empty',
#  'find Path -readable -d -noleaf',
#  'find Path -inum Timespan -prune -empty',
#  'find Path -d -user Timespan -path Regex',
#  'find Path -links Timespan -ctime Timespan -daystart',
#  'find Path -iwholename Regex -readable -follow',
#  'find Path -noignore_readdir_race -lname Regex -executable',
#  'find Path -ipath Regex -iname Regex -atime Timespan',
#  'find Path -name Regex -fprintf -used Timespan',
#  'find Path -ipath Regex -iname Regex -warn',
#  'find Path -noleaf -fprintf -samefile File',
#  'find Path -quit -used Timespan -print0',
#  'find Path -prune -empty -ilname Regex',
#  'find Path -wholename Regex -mmin Timespan -true',
#  'find Path -depth -fprint File -false',
#  'find Path -samefile File -executable -print0',
#  'find Path -mtime Timespan -inum Timespan -group Timespan',
#  'find Path -daystart -fprintf -size Timespan',
#  'find Path -empty -size Timespan -path Regex',
#  'find Path -depth -mount -false',
#  'find Path -mmin Timespan -samefile File -amin Timespan',
#  'find Path -iname Regex -d -warn',
#  'find Path -ctime Timespan -help -user Timespan',
#  'find Path -writable -ipath Regex -ignore_readdir_race',
#  'find Path -name Regex -mtime Timespan -depth',
#  'find Path -mount -fprint0 File -xdev',
#  'find Path -depth -delete -false',
#  'find Path -depth -iname Regex -fprint0 File',
#  'find Path -mtime Timespan -noleaf -help',
#  'find Path -help -fprint0 File -print0',
#  'find Path -writable -daystart -noleaf',
#  'find Path -print -path Regex',
#  'find Path -links Timespan -wholename Regex -size Timespan',
#  'find Path -d -empty -print0',
#  'find Path -inum Timespan -atime Timespan -user Timespan',
#  'find Path -mtime Timespan -prune -user Timespan',
#  'find Path -name Regex -readable -mtime Timespan',
#  'find Path -fprintf -amin Timespan -follow',
#  'find Path -name Regex -inum Timespan -xdev',
#  'find Path -ipath Regex -inum Timespan -prune',
#  'find Path -version -d -n',
#  'find Path -ls -quit -noignore_readdir_race',
#  'find Path -version -exec -noleaf',
#  'find Path -prune -noleaf -cmin Timespan',
#  'find Path -inum Timespan -ctime Timespan -lname Regex',
#  'find Path -noleaf -regex Regex -print0',
#  'find Path -group Timespan -fprint File -follow',
#  'find Path -fls File -empty -amin Timespan',
#  'find Path -used Timespan -fprint File -path Regex',
#  'find Path -daystart -ignore_readdir_race -ilname Regex',
#  'find Path -links Timespan -ctime Timespan -ignore_readdir_race',
#  'find Path -print -quit -daystart',
#  'find Path -daystart -regex Regex -empty',
#  'find Path -quit -d -wholename Regex',
#  'find Path -iwholename Regex -readable -atime Timespan',
#  'find Path -nogroup -prune -true',
#  'find Path -version -P -n',
#  'find Path -fls File -ilname Regex -false',
#  'find Path -daystart -lname Regex -samefile File',
#  'find Path -delete -mount -true',
#  'find Path -version -fls File -wholename Regex',
#  'find Path -regex Regex -warn',
#  'find Path -nouser -empty -cmin Timespan',
#  'find Path -iregex Regex -iname Regex -group Timespan',
#  'find Path -links Timespan -lname Regex -empty',
#  'find Path -readable -mmin Timespan -fprint0 File',
#  'find Path -writable -xdev',
#  'find Path -ctime Timespan -fprint0 File -fprint File',
#  'find Path -version -user Timespan -cmin Timespan',
#  'find Path -prune -executable -path Regex',
#  'find Path -used Timespan -ilname Regex -xdev',
#  'find Path -print -regex Regex -xdev',
#  'find Path -links Timespan -iname Regex -fprint0 File',
#  'find Path -depth -noleaf -regex Regex',
#  'find Path -quit -nogroup -executable',
#  'find Path -user Timespan -ilname Regex -true',
#  'find Path -iregex Regex -used Timespan -path Regex',
#  'find Path -name Regex -version -anewer Timespan',
#  'find Path -depth -iregex Regex',
#  'find Path -mount -ilname Regex -path Regex',
#  'find Path -fls File -noleaf -atime Timespan',
#  'find Path -ignore_readdir_race -ilname Regex -fprint0 File',
#  'find Path -writable -depth -iregex Regex',
#  'find Path -version -ok -fprintf',
#  'find Path -name Regex -version -iname Regex',
#  'find Path -name Regex -iname Regex -true',
#  'find Path -version -P -O',
#  'find Path -quit -lname Regex -ignore_readdir_race',
#  'find Path -ipath Regex -daystart -print0',
#  'find Path -nouser -cmin Timespan -size Timespan',
#  'find Path -nouser -daystart -true',
#  'find Path -nogroup -ipath Regex -user Timespan',
#  'find Path -mtime Timespan -help -O',
#  'find Path -samefile File -mount -true',
#  'find Path -version -newerXY Timespan -iname Regex',
#  'find Path -name Regex -ipath Regex -executable',
#  'find Path -name Regex -inum Timespan -fprint File',
#  'find Path -readable -wholename Regex -true',
#  'find Path -executable -size Timespan -follow',
#  'find Path -mtime Timespan -used Timespan -samefile File',
#  'find Path -nouser -noleaf -false',
#  'find Path -nouser -mtime Timespan -lname Regex',
#  'find Path -iwholename Regex -version -noignore_readdir_race',
#  'find Path -quit -ctime Timespan -ignore_readdir_race',
#  'find Path -links Timespan -ignore_readdir_race -follow',
#  'find Path -fprintf -executable -false',
#  'find Path -ignore_readdir_race -atime Timespan',
#  'find Path -writable -empty',
#  'find Path -version -exec -n',
#  'find Path -writable -mmin Timespan -false',
#  'find Path -d -used Timespan -cmin Timespan',
#  'find Path -fls File -wholename Regex -warn',
#  'find Path -links Timespan -depth -iregex Regex',
#  'find Path -depth -inum Timespan -path Regex',
#  'find Path -iwholename Regex -fprintf -user Timespan',
#  'find Path -delete -help -used Timespan',
#  'find Path -ls -iwholename Regex -ipath Regex',
#  'find Path -nouser -inum Timespan -false',
#  'find Path -nogroup -inum Timespan',
#  'find Path -mmin Timespan -atime Timespan -false',
#  'find Path -lname Regex -user Timespan -executable',
#  'find Path -links Timespan -iname Regex -ctime Timespan',
#  'find Path -samefile File -mount -fprint0 File',
#  'find Path -depth -wholename Regex -ignore_readdir_race',
#  'find Path -name Regex -or -nogroup',
#  'find Path -version -anewer Timespan -noignore_readdir_race',
#  'find Path -name Regex -mtime Timespan -d',
#  'find Path -prune -samefile File -amin Timespan',
#  'find Path -iwholename Regex -ipath Regex -regex Regex',
#  'find Path -iregex Regex -regex Regex -xdev',
#  'find Path -atime Timespan -cmin Timespan -fprint0 File',
#  'find Path -links Timespan -samefile File -atime Timespan',
#  'find Path -daystart -noleaf -atime Timespan',
#  'find Path -iregex Regex -d -empty',
#  'find Path -print -readable -depth',
#  'find Path -version -print0 -context Regex',
#  'find Path -empty -used Timespan -print0',
#  'find Path -iwholename Regex -print -lname Regex',
#  'find Path -ls -iname Regex -daystart',
#  'find Path -fls File -size Timespan -follow',
#  'find Path -ls -inum Timespan -fprint File',
#  'find Path -version -ok -help',
#  'find Path -fprintf -cmin Timespan -size Timespan',
#  'find Path -iname Regex -wholename Regex -cmin Timespan',
#  'find Path -cmin Timespan -print0 -amin Timespan',
#  'find Path -ipath Regex -daystart -false',
#  'find Path -iname Regex -user Timespan -fprint0 File',
#  'find Path -nouser -empty -size Timespan',
#  'find Path -name Regex -group Timespan -path Regex',
#  'find Path -noleaf -print0 -fprint File',
#  'find Path -ls -writable -xdev',
#  'find Path -wholename Regex -samefile File -true',
#  'find Path -ls -empty -fprint0 File',
#  'find Path -inum Timespan -empty -path Regex',
#  'find Path -regex Regex -used Timespan -group Timespan',
#  'find Path -name Regex -depth -group Timespan',
#  'find Path -fls File -noignore_readdir_race -print0',
#  'find Path -iwholename Regex -mmin Timespan -fprint File',
#  'find Path -ipath Regex -atime Timespan -xdev',
#  'find Path -depth -fprint0 File',
#  'find Path -empty -samefile File -atime Timespan',
#  'find Path -writable -ctime Timespan -path Regex',
#  'find Path -print -depth -samefile File',
#  'find Path -ipath Regex -iname Regex -noleaf',
#  'find Path -prune -ctime Timespan -wholename Regex',
#  'find Path -nouser -delete -used Timespan',
#  'find Path -readable -used Timespan -follow',
#  'find Path -name Regex -ipath Regex -noleaf',
#  'find Path -ctime Timespan -group Timespan -fprint File',
#  'find Path -fls File -user Timespan -executable',
#  'find Path -quit -depth -noleaf',
#  'find Path -nogroup -version -cmin Timespan',
#  'find Path -name Regex -nouser',
#  'find Path -o -help -group Timespan',
#  'find Path -daystart -size Timespan -path Regex',
#  'find Path -noignore_readdir_race -used Timespan -ilname Regex',
#  'find Path -ipath Regex -inum Timespan -fprint File',
#  'find Path -iwholename Regex -version -fprint File',
#  'find Path -ctime Timespan -atime Timespan -false',
#  'find Path -links Timespan -executable -follow',
#  'find Path -samefile File -fprint0 File -amin Timespan',
#  'find Path -help -empty -executable',
#  'find Path -ls -ignore_readdir_race -print0',
#  'find Path -version -executable -true',
#  'find Path -regex Regex -print0 -fprint File',
#  'find Path -samefile File -true -follow',
#  'find Path -writable -iname Regex -wholename Regex',
#  'find Path -fls File -inum Timespan -used Timespan',
#  'find Path -wholename Regex',
#  'find Path -nouser -noignore_readdir_race -used Timespan',
#  'find Path -ls -links Timespan -print0',
#  'find Path -version -regex Regex -ilname Regex',
#  'find Path -iname Regex -empty -used Timespan',
#  'find Path -d -atime Timespan -follow',
#  'find Path -mtime Timespan -wholename Regex -print0',
#  'find Path -name Regex -lname Regex -help',
#  'find Path -print -nouser -ctime Timespan',
#  'find Path -delete -noignore_readdir_race -ignore_readdir_race',
#  'find Path -nouser -fprintf -fprint0 File',
#  'find Path -depth -inum Timespan -true',
#  'find Path -writable -mtime Timespan -amin Timespan',
#  'find Path -iwholename Regex -quit -mount',
#  'find Path -nouser -ignore_readdir_race -mount',
#  'find Path -warn -mount -true',
#  'find Path -ctime Timespan -group Timespan -executable',
#  'find Path -help -user Timespan -print0',
#  'find Path -version -delete -user Timespan',
#  'find Path -ls -prune -ctime Timespan',
#  'find Path -iregex Regex -iname Regex -daystart',
#  'find Path -nogroup -delete -true',
#  'find Path -iwholename Regex -ctime Timespan -empty',
#  'find Path -links Timespan -prune -help',
#  'find Path -links Timespan -user Timespan -cmin Timespan',
#  'find Path -writable -d -daystart',
#  'find Path -nouser -d -path Regex',
#  'find Path -print -iregex Regex -group Timespan',
#  'find Path -prune -ignore_readdir_race -cmin Timespan',
#  'find Path -delete -noleaf -ignore_readdir_race',
#  'find Path -d -mmin Timespan -ilname Regex',
#  'find Path -ignore_readdir_race -executable -ilname Regex',
#  'find Path -name Regex -ctime Timespan -used Timespan',
#  'find Path -depth -mount -fprint File',
#  'find Path -noignore_readdir_race -user Timespan -path Regex',
#  'find Path -name Regex -depth -follow',
#  'find Path -version -ctime Timespan -newer Timespan',
#  'find Path -lname Regex -samefile File -follow',
#  'find Path -writable -empty -user Timespan',
#  'find Path -writable -depth -samefile File',
#  'find Path -iwholename Regex -readable -lname Regex',
#  'find Path -fls File -empty -size Timespan',
#  'find Path -ipath Regex -warn -path Regex',
#  'find Path -ipath Regex -iregex Regex -warn',
#  'find Path -iregex Regex -noleaf -xdev',
#  'find Path -nouser -nogroup -amin Timespan',
#  'find Path -iregex Regex -prune -fprint File',
#  'find Path -ipath Regex -iregex Regex -atime Timespan',
#  'find Path -quit -readable -fprint0 File',
#  'find Path -ls -size Timespan -path Regex',
#  'find Path -warn -ilname Regex -size Timespan',
#  'find Path -depth -mmin Timespan -help',
#  'find Path -d -user Timespan -size Timespan',
#  'find Path -writable -help -uid',
#  'find Path -print -used Timespan -group Timespan',
#  'find Path -print -inum Timespan -daystart',
#  'find Path -depth -noignore_readdir_race -executable',
#  'find Path -readable -links Timespan -xdev',
#  'find Path -ipath Regex -d -print0',
#  'find Path -prune -help -print0',
#  'find Path -nouser -ctime Timespan -follow',
#  'find Path -nouser -noleaf -mount',
#  'find Path -noignore_readdir_race -empty -fprint0 File',
#  'find Path -help -samefile File -fprint0 File',
#  'find Path -name Regex -writable -daystart',
#  'find Path -depth -inum Timespan -help',
#  'find Path -iwholename Regex -mount -xdev',
#  'find Path -writable -atime Timespan -fprint File',
#  'find Path -empty -used Timespan -size Timespan',
#  'find Path -nogroup -lname Regex -cmin Timespan',
#  'find Path -noleaf -regex Regex -cmin Timespan',
#  'find Path -nogroup -d -size Timespan',
#  'find Path -depth -iname Regex -fprint File',
#  'find Path -print -used Timespan -cmin Timespan',
#  'find Path -mtime Timespan -noignore_readdir_race -fprint0 File',
#  'find Path -inum Timespan -fprint File -xdev',
#  'find Path -quit -used Timespan',
#  'find Path -version -mmin Timespan -fprint0 File',
#  'find Path -d -wholename Regex -path Regex',
#  'find Path -noignore_readdir_race -mmin Timespan -group Timespan',
#  'find Path -links Timespan -ignore_readdir_race -path Regex',
#  'find Path -version -mmin Timespan -warn',
#  'find Path -mtime Timespan -fls File -user Timespan',
#  'find Path -depth -noignore_readdir_race -group Timespan',
#  'find Path -quit -links Timespan -ilname Regex',
#  'find Path -nouser -fprintf -used Timespan',
#  'find Path -iname Regex -mmin Timespan -fprint0 File',
#  'find Path -ipath Regex -fls File',
#  'find Path -inum Timespan -noignore_readdir_race -path Regex',
#  'find Path -nogroup -samefile File -ilname Regex',
#  'find Path -ls -regex Regex -help',
#  'find Path -quit -iregex Regex -size Timespan',
#  'find Path -mtime Timespan -used Timespan -warn',
#  'find Path -ctime Timespan -print0',
#  'find Path -mmin Timespan -samefile File -follow',
#  'find Path -links Timespan -iname Regex -d',
#  'find Path -writable -mmin Timespan -amin Timespan',
#  'find Path -version -iregex Regex -follow',
#  'find Path -mtime Timespan -noignore_readdir_race -ilname Regex',
#  'find Path -depth -ilname Regex -follow',
#  'find Path -ipath Regex -warn -atime Timespan',
#  'find Path -name Regex -depth -fls File',
#  'find Path -fprintf -path Regex',
#  'find Path -writable -inum Timespan -iname Regex',
#  'find Path -writable -warn -path Regex',
#  'find Path -nouser -writable',
#  'find Path -d -wholename Regex -warn',
#  'find Path -or -version -cmin Timespan',
#  'find Path -iregex Regex -ctime Timespan',
#  'find Path -iwholename Regex -print -size Timespan',
#  'find Path -ctime Timespan -wholename Regex -daystart',
#  'find Path -prune -wholename Regex -regex Regex',
#  'find Path -name Regex -regex Regex -path Regex',
#  'find Path -quit -noleaf -fprint File',
#  'find Path -ignore_readdir_race -mmin Timespan -follow',
#  'find Path -name Regex -group Timespan -xdev',
#  'find Path -readable -empty -xdev',
#  'find Path -noignore_readdir_race -size Timespan -true',
#  'find Path -version -mtime Timespan -xdev',
#  'find Path -print -nouser -readable',
#  'find Path -version -anewer Timespan -amin Timespan',
#  'find Path -size Timespan -path Regex -follow',
#  'find Path -iwholename Regex -print -noignore_readdir_race',
#  'find Path -print -nogroup -wholename Regex',
#  'find Path -delete -ignore_readdir_race -mount',
#  'find Path -links Timespan -follow',
#  'find Path -writable -ignore_readdir_race -atime Timespan',
#  'find Path -name Regex -or -empty',
#  'find Path -nouser -quit -nogroup',
#  'find Path -inum Timespan -ignore_readdir_race -group Timespan',
#  'find Path -wholename Regex -noignore_readdir_race -ilname Regex',
#  'find Path -writable -cmin Timespan -true',
#  'find Path -mtime Timespan -used Timespan -executable',
#  'find Path -ls -ipath Regex -regex Regex',
#  'find Path -regex Regex -empty -atime Timespan',
#  'find Path -version -depth -ignore_readdir_race',
#  'find Path -mtime Timespan -wholename Regex -executable',
#  'find Path -regex Regex -atime Timespan -executable',
#  'find Path -fprintf -user Timespan -true',
#  'find Path -iwholename Regex -delete',
#  'find Path -wholename Regex -empty -executable',
#  'find Path -links Timespan -delete -fprint0 File',
#  'find Path -daystart -xdev',
#  'find Path -noignore_readdir_race -fprint File -xdev',
#  'find Path -print -ilname Regex -false',
#  'find Path -nogroup -used Timespan -path Regex',
#  'find Path -nouser -delete -ignore_readdir_race',
#  'find Path -ls -writable -daystart',
#  'find Path -print -quit -cmin Timespan',
#  'find Path -version -wholename Regex -size Timespan',
#  'find Path -mtime Timespan -daystart -ilname Regex',
#  'find Path -ls -nogroup -print0',
#  'find Path -fls File -iregex Regex -used Timespan',
#  'find Path -delete -executable -path Regex',
#  'find Path -version -mtime Timespan -empty',
#  'find Path -fprintf -used Timespan -path Regex',
#  'find Path -readable -help -fprint File',
#  'find Path -lname Regex -mount -follow',
#  'find Path -regex Regex -atime Timespan -ilname Regex',
#  'find Path -mmin Timespan -group Timespan -ilname Regex',
#  'find Path -ctime Timespan -group Timespan -atime Timespan',
#  'find Path -noleaf -used Timespan -samefile File',
#  'find Path -depth -mmin Timespan -used Timespan',
#  'find Path -depth -fprint File -size Timespan',
#  'find Path -iwholename Regex -or -mmin Timespan',
#  'find Path -iwholename Regex -ipath Regex -executable',
#  'find Path -writable -version -mmin Timespan',
#  'find Path -links Timespan -fprint0 File -print0',
#  'find Path -name Regex -regex Regex -executable',
#  'find Path -name Regex -inum Timespan -samefile File',
#  'find Path -version -iname Regex -P',
#  'find Path -iregex Regex -fprint0 File -true',
#  'find Path -noignore_readdir_race -help -true',
#  'find Path -quit -false -follow',
#  'find Path -lname Regex -user Timespan -amin Timespan',
#  'find Path -quit -links Timespan -samefile File',
#  'find Path -mtime Timespan -group Timespan -mount',
#  'find Path -name Regex -ignore_readdir_race -help',
#  'find Path -version -ipath Regex -help',
#  'find Path -ls -inum Timespan -path Regex',
#  'find Path -version -iregex Regex -files0-from File',
#  'find Path -nouser -quit -version',
#  'find Path -print -empty -print0',
#  'find Path -nogroup -d -noignore_readdir_race',
#  'find Path -print -depth -warn',
#  'find Path -lname Regex -mmin Timespan -path Regex',
#  'find Path -ls -nogroup -mtime Timespan',
#  'find Path -iregex Regex -cmin Timespan -executable',
#  'find Path -regex Regex -used Timespan -mount',
#  'find Path -noleaf -true -xdev',
#  'find Path -writable -ignore_readdir_race -empty',
#  'find Path -links Timespan -fprint File',
#  'find Path -used Timespan -cmin Timespan -false',
#  'find Path -version -prune -delete',
#  'find Path -noignore_readdir_race -atime Timespan',
#  'find Path -writable -delete -warn',
#  'find Path -nogroup -mount -print0',
#  'find Path -prune -ilname Regex -follow',
#  'find Path -nogroup -iname Regex -cmin Timespan',
#  'find Path -delete -fprint0 File -path Regex',
#  'find Path -ctime Timespan -noignore_readdir_race',
#  'find Path -mmin Timespan -warn -path Regex',
#  'find Path -mtime Timespan -mount',
#  'find Path -nogroup -version -fprint File',
#  'find Path -mtime Timespan -lname Regex -mount',
#  'find Path -ipath Regex -ctime Timespan -follow',
#  'find Path -iwholename Regex -quit -wholename Regex',
#  'find Path -readable -mmin Timespan',
#  'find Path -iwholename Regex -mtime Timespan -regex Regex',
#  'find Path -links Timespan -ilname Regex -size Timespan',
#  'find Path -mtime Timespan -executable -true',
#  'find Path -iregex Regex -ignore_readdir_race -true',
#  'find Path -ctime Timespan -delete -group Timespan',
#  'find Path -noleaf -user Timespan -executable',
#  'find Path -iwholename Regex -true -path Regex',
#  'find Path -ipath Regex -iregex Regex -executable',
#  'find Path -o -prune -help',
#  'find Path -delete -empty -false',
#  'find Path -links Timespan -ilname Regex',
#  'find Path -readable -used Timespan -warn',
#  'find Path -version -newerXY Timespan -path Regex',
#  'find Path -nouser -used Timespan -path Regex',
#  'find Path -print -links Timespan -depth',
#  'find Path -print -mtime Timespan -empty',
#  'find Path -name Regex -wholename Regex -user Timespan',
#  'find Path -quit -used Timespan -true',
#  'find Path -iwholename Regex -regex Regex -false',
#  'find Path -fls File -ignore_readdir_race',
#  'find Path -wholename Regex -false -path Regex',
#  'find Path -version -fprint0 File -print0',
#  'find Path -ls -d -fprint File',
#  'find Path -d -warn -mount',
#  'find Path -version -help -warn',
#  'find Path -fprintf -samefile File -size Timespan',
#  'find Path -nouser -wholename Regex -ignore_readdir_race',
#  'find Path -nogroup -ipath Regex -iname Regex',
#  'find Path -ipath Regex -help -O',
#  'find Path -depth -cmin Timespan -true',
#  'find Path -version -prune -ignore_readdir_race',
#  'find Path -ignore_readdir_race -print0 -xdev',
#  'find Path -warn -atime Timespan -true',
#  'find Path -ls -prune -lname Regex',
#  'find Path -daystart -executable -path Regex',
#  'find Path -name Regex -nouser -amin Timespan',
#  'find Path -fprintf -gid -true',
#  'find Path -ls -group Timespan -path Regex',
#  'find Path -or -version -d',
#  'find Path -fprintf -atime Timespan -amin Timespan',
#  'find Path -or -version -cnewer Timespan',
#  'find Path -noleaf -warn',
#  'find Path -name Regex -prune -samefile File',
#  'find Path -iwholename Regex -ctime Timespan -lname Regex',
#  'find Path -help -mount -cmin Timespan',
#  'find Path -version -daystart -warn',
#  'find Path -help -user Timespan -context Regex',
#  'find Path -name Regex -iregex Regex -executable',
#  'find Path -readable -empty -used Timespan',
#  'find Path -prune -samefile File -fprint0 File',
#  'find Path -writable -false -amin Timespan',
#  'find Path -nouser -ipath Regex -false',
#  'find Path -quit -nogroup -fprint0 File',
#  'find Path -quit -follow',
#  'find Path -ls -o -path Regex',
#  'find Path -ignore_readdir_race -size Timespan',
#  'find Path -user Timespan -fprint File -false',
#  'find Path -fls File -fprintf -size Timespan',
#  'find Path -quit -regex Regex -warn',
#  'find Path -ls -wholename Regex -daystart',
#  'find Path -readable -d -warn',
#  'find Path -mtime Timespan -d -fprint File',
#  'find Path -wholename Regex -group Timespan -mount',
#  'find Path -group Timespan -atime Timespan -print0',
#  'find Path -mtime Timespan -cmin Timespan',
#  'find Path -nogroup -samefile File -user Timespan',
#  'find Path -mtime Timespan -iname Regex -empty',
#  'find Path -nogroup -depth',
#  'find Path -mtime Timespan -fprint0 File -amin Timespan',
#  'find Path -version -ignore_readdir_race -context Regex',
#  'find Path -ls -delete -path Regex',
#  'find Path -version -prune -noleaf',
#  'find Path -name Regex -iname Regex -noignore_readdir_race',
#  'find Path -d -daystart -ilname Regex',
#  'find Path -user Timespan -size Timespan -xdev',
#  'find Path -writable -ipath Regex -fprint0 File',
#  'find Path -ipath Regex -help -context Regex',
#  'find Path -delete -mount -fprint0 File',
#  'find Path -user Timespan -ilname Regex -amin Timespan',
#  'find Path -iwholename Regex -or -fls File',
#  'find Path -readable -cmin Timespan -fprint0 File',
#  'find Path -quit -empty -print0',
#  'find Path -depth -user Timespan -xdev',
#  'find Path -links Timespan -mtime Timespan -false',
#  'find Path -writable -ctime Timespan -ignore_readdir_race',
#  'find Path -quit -empty',
#  'find Path -readable -inum Timespan -d',
#  'find Path -iregex Regex -lname Regex',
#  'find Path -mount -cmin Timespan -xdev',
#  'find Path -ls -group Timespan -atime Timespan',
#  'find Path -quit -depth -ilname Regex',
#  'find Path -writable -readable -depth',
#  'find Path -prune -help -user Timespan',
#  'find Path -noleaf -ignore_readdir_race -help',
#  'find Path -writable -depth -fprint0 File',
#  'find Path -mtime Timespan -fprintf -size Timespan',
#  'find Path -regex Regex -samefile File -mount',
#  'find Path -cmin Timespan -ilname Regex -false',
#  'find Path -quit -nogroup -ipath Regex',
#  'find Path -iwholename Regex -fls File -warn',
#  'find Path -daystart -ignore_readdir_race -fprint0 File',
#  'find Path -quit -empty -user Timespan',
#  'find Path -ipath Regex -regex Regex -xdev',
#  'find Path -quit -version -help',
#  'find Path -ignore_readdir_race -empty -print0',
#  'find Path -lname Regex -ignore_readdir_race -used Timespan',
#  'find Path -used Timespan -print0 -amin Timespan',
#  'find Path -mtime Timespan -ctime Timespan -lname Regex',
#  'find Path -ls -noleaf -true',
#  'find Path -noignore_readdir_race -lname Regex -used Timespan',
#  'find Path -ls -nouser -noleaf',
#  'find Path -print -wholename Regex -fprint0 File',
#  'find Path -inum Timespan -prune -true',
#  'find Path -nouser -help -atime Timespan',
#  'find Path -ipath Regex -daystart -mount',
#  'find Path -group Timespan -warn -size Timespan',
#  'find Path -iwholename Regex -noignore_readdir_race -help',
#  'find Path -name Regex -daystart -samefile File',
#  'find Path -links Timespan -iname Regex -false',
#  'find Path -print -inum Timespan -mmin Timespan',
#  'find Path -fls File -ctime Timespan -delete',
#  'find Path -version -mtime Timespan -warn',
#  'find Path -quit -regex Regex -false',
#  'find Path -lname Regex -regex Regex -used Timespan',
#  'find Path -version -inum Timespan -warn',
#  'find Path -depth -ignore_readdir_race -fprint0 File',
#  'find Path -prune -regex Regex -xdev',
#  'find Path -iname Regex -used Timespan -samefile File',
#  'find Path -d -ignore_readdir_race -amin Timespan',
#  'find Path -readable -inum Timespan -help',
#  'find Path -print -used Timespan -mount',
#  'find Path -regex Regex -samefile File -follow',
#  'find Path -depth -noleaf -used Timespan',
#  'find Path -d -lname Regex -fprint0 File',
#  'find Path -noignore_readdir_race -mmin Timespan -atime Timespan',
#  'find Path -print -executable',
#  'find Path -depth -iname Regex -ignore_readdir_race',
#  'find Path -inum Timespan -prune -mmin Timespan',
#  'find Path -writable -ignore_readdir_race -ilname Regex',
#  'find Path -d -mmin Timespan -user Timespan',
#  'find Path -version -user Timespan -false',
#  'find Path -name Regex -iname Regex -lname Regex',
#  'find Path -nouser -d -noleaf',
#  'find Path -ctime Timespan -user Timespan -false',
#  'find Path -readable -size Timespan -xdev',
#  'find Path -d -mount -user Timespan',
#  'find Path -print -daystart -mount',
#  'find Path -version -Olevel -false',
#  'find Path -print -wholename Regex -warn',
#  'find Path -inum Timespan -d -samefile File',
#  'find Path -inum Timespan -false -amin Timespan',
#  'find Path -prune -iname Regex -ilname Regex',
#  'find Path -iwholename Regex -fls File -mount',
#  'find Path -nouser -ctime Timespan',
#  'find Path -ipath Regex -mtime Timespan -mmin Timespan',
#  'find Path -empty -atime Timespan -false',
#  'find Path -version -mmin Timespan -ilname Regex',
#  'find Path -ctime Timespan -false -path Regex',
#  'find Path -quit -fls File -ctime Timespan',
#  'find Path -nogroup -ctime Timespan -ignore_readdir_race',
#  'find Path -readable -lname Regex -warn',
#  'find Path -wholename Regex -noleaf -used Timespan',
#  'find Path -fls File -samefile File -amin Timespan',
#  'find Path -version -links Timespan -mmin Timespan',
#  'find Path -writable -ilname Regex',
#  'find Path -name Regex -iname Regex -wholename Regex',
#  'find Path -iwholename Regex -print -wholename Regex',
#  'find Path -noleaf -user Timespan -path Regex',
#  'find Path -iwholename Regex -empty -amin Timespan',
#  'find Path -links Timespan -delete -path Regex',
#  'find Path -writable -help -amin Timespan',
#  'find Path -writable -wholename Regex -atime Timespan',
#  'find Path -quit -ignore_readdir_race -print0',
#  'find Path -nogroup -ctime Timespan -mount',
#  'find Path -prune -iname Regex -samefile File',
#  'find Path -cmin Timespan -executable -follow',
#  'find Path -prune -help -context Regex',
#  'find Path -fls File -inum Timespan -regex Regex',
#  'find Path -delete -fprint File',
#  'find Path -wholename Regex -mount -executable',
#  'find Path -version -warn -okdir',
#  'find Path -writable -noleaf -size Timespan',
#  'find Path -ls -daystart -fprint0 File',
#  'find Path -version -cmin Timespan -fprint File',
#  'find Path -name Regex -fprintf -samefile File',
#  'find Path -quit -inum Timespan -ctime Timespan',
#  'find Path -name Regex -iregex Regex -inum Timespan',
#  'find Path -help -samefile File -ilname Regex',
#  'find Path -regex Regex -group Timespan -cmin Timespan',
#  'find Path -ls -used Timespan -executable',
#  'find Path -version -ctime Timespan -n',
#  'find Path -ipath Regex -empty -fprint0 File',
#  'find Path -nogroup -version -amin Timespan',
#  'find Path -version -group Timespan -xdev',
#  'find Path -noignore_readdir_race -print0 -false',
#  'find Path -prune -lname Regex -ilname Regex',
#  'find Path -depth -size Timespan -false',
#  'find Path -inum Timespan -executable -print0',
#  'find Path -version -iname Regex -context Regex',
#  'find Path -help -follow',
#  'find Path -name Regex -ipath Regex -fprint0 File',
#  'find Path -fls File -inum Timespan -wholename Regex',
#  'find Path -name Regex -cmin Timespan -fprint File',
#  'find Path -fls File -ignore_readdir_race -executable',
#  'find Path -inum Timespan -empty -size Timespan',
#  'find Path -d -daystart -fprint0 File',
#  'find Path -wholename Regex -lname Regex -used Timespan',
#  'find Path -iwholename Regex -nouser -fprint File',
#  'find Path -wholename Regex -daystart -mount',
#  'find Path -empty -user Timespan -false',
#  'find Path -samefile File -cmin Timespan -path Regex',
#  'find Path -writable -d -size Timespan',
#  'find Path -ipath Regex -mtime Timespan -ignore_readdir_race',
#  'find Path -name Regex -ipath Regex -atime Timespan',
#  'find Path -nouser -iname Regex -noleaf',
#  'find Path -ignore_readdir_race -print0 -path Regex',
#  'find Path -name Regex -cmin Timespan -fprint0 File',
#  'find Path -ls -samefile File -ilname Regex',
#  'find Path -fprint File -amin Timespan -xdev',
#  'find Path -print -version -mtime Timespan',
#  'find Path -links Timespan -prune -daystart',
#  'find Path -quit -ctime Timespan -ilname Regex',
#  'find Path -lname Regex -true -amin Timespan',
#  'find Path -version -gid -user Timespan',
#  'find Path -iwholename Regex -ctime Timespan -help',
#  'find Path -iname Regex -print0 -size Timespan',
#  'find Path -inum Timespan -used Timespan -follow',
#  'find Path -prune -mmin Timespan -true',
#  'find Path -writable -noleaf -cmin Timespan',
#  'find Path -daystart -help -path Regex',
#  'find Path -nouser -nogroup -empty',
#  'find Path -ctime Timespan -executable -follow',
#  'find Path -mmin Timespan -executable -false',
#  'find Path -iwholename Regex -prune -daystart',
#  'find Path -quit -fprintf -group Timespan',
#  'find Path -inum Timespan -used Timespan -warn',
#  'find Path -prune -regex Regex -mount',
#  'find Path -nouser -ipath Regex -ignore_readdir_race',
#  'find Path -cmin Timespan -fprint0 File -true',
#  'find Path -version -d -O',
#  'find Path -noignore_readdir_race -ilname Regex -print0',
#  'find Path -help -mount -O',
#  'find Path -readable -wholename Regex -atime Timespan',
#  'find Path -noleaf -samefile File -path Regex',
#  'find Path -name Regex -d -print0',
#  'find Path -iregex Regex -ctime Timespan -mmin Timespan',
#  'find Path -d -help -used Timespan',
#  'find Path -quit -delete -size Timespan',
#  'find Path -iregex Regex -warn -mount',
#  'find Path -version -executable -follow',
#  'find Path -depth -help -mount',
#  'find Path -regex Regex -atime Timespan',
#  'find Path -iregex Regex -noleaf -ilname Regex',
#  'find Path -name Regex -nouser -d',
#  'find Path -noignore_readdir_race -ignore_readdir_race -path Regex',
#  'find Path -mmin Timespan -warn -size Timespan',
#  'find Path -inum Timespan -empty -fprint0 File',
#  'find Path -ls -print -version',
#  'find Path -print -noleaf -atime Timespan',
#  'find Path -ctime Timespan -user Timespan -path Regex',
#  'find Path -lname Regex -mmin Timespan -xdev',
#  'find Path -ipath Regex -size Timespan -false',
#  'find Path -mmin Timespan -used Timespan -mount',
#  'find Path -inum Timespan -warn -samefile File',
#  'find Path -name Regex -quit -mmin Timespan',
#  'find Path -quit -noignore_readdir_race -noleaf',
#  'find Path -fls File -wholename Regex -samefile File',
#  'find Path -warn -executable -false',
#  'find Path -atime Timespan -executable -ilname Regex',
#  'find Path -links Timespan -noignore_readdir_race -noleaf',
#  'find Path -group Timespan -warn -true',
#  'find Path -help -empty -size Timespan',
#  'find Path -ls -o -wholename Regex',
#  'find Path -readable -group Timespan -samefile File',
#  'find Path -name Regex -links Timespan -mount',
#  'find Path -iregex Regex -delete -ilname Regex',
#  'find Path -ls -fls File -regex Regex',
#  'find Path -version -Olevel -mount',
#  'find Path -help -path Regex',
#  'find Path -print -ctime Timespan -delete',
#  'find Path -ipath Regex -mmin Timespan -regex Regex',
#  'find Path -print -nouser -links Timespan',
#  'find Path -version -mount -fprint File',
#  'find Path -delete -noleaf -false',
#  'find Path -nogroup -links Timespan -path Regex',
#  'find Path -name Regex -delete -fprint0 File',
#  'find Path -ls -ipath Regex -size Timespan',
#  'find Path -ls -fls File -follow',
#  'find Path -depth -help -path Regex',
#  'find Path -fls File -delete -mount',
#  'find Path -used Timespan -print0 -path Regex',
#  'find Path -d -user Timespan -fprint File',
#  'find Path -used Timespan -mount -xdev',
#  'find Path -true -amin Timespan -follow',
#  'find Path -noignore_readdir_race -user Timespan -true',
#  'find Path -writable -mtime Timespan -samefile File',
#  'find Path -wholename Regex -delete -noignore_readdir_race',
#  'find Path -version -prune -newer Timespan',
#  'find Path -mount -false -true',
#  'find Path -print -iregex Regex -daystart',
#  'find Path -ls -help -samefile File',
#  'find Path -quit -lname Regex -path Regex',
#  'find Path -iwholename Regex -or -wholename Regex',
#  'find Path -nouser -d -empty',
#  'find Path -wholename Regex -samefile File',
#  'find Path -ls -lname Regex -path Regex',
#  'find Path -writable -ipath Regex -amin Timespan',
#  'find Path -version -newer Timespan -fprint File',
#  'find Path -print -lname Regex -print0',
#  'find Path -depth -noignore_readdir_race -user Timespan',
#  'find Path -fls File -group Timespan -fprint File',
#  'find Path -iname Regex -help -fprint0 File',
#  'find Path -writable -nogroup -mmin Timespan',
#  'find Path -mmin Timespan -used Timespan -amin Timespan',
#  'find Path -mmin Timespan -user Timespan -executable',
#  'find Path -version -user Timespan -size Timespan',
#  'find Path -name Regex -or -mtime Timespan',
#  'find Path -ctime Timespan -lname Regex -true',
#  'find Path -iwholename Regex -iregex Regex -executable',
#  'find Path -print -links Timespan -true',
#  'find Path -print -quit -ilname Regex',
#  'find Path -depth -fprintf -samefile File',
#  'find Path -quit -version -n',
#  'find Path -readable -prune -ctime Timespan',
#  'find Path -daystart -print0 -xdev',
#  'find Path -mtime Timespan -fls File -print0',
#  'find Path -empty -follow',
#  'find Path -version -newerXY Timespan -prune',
#  'find Path -name Regex -iregex Regex -false',
#  'find Path -fls File -iregex Regex -mount',
#  'find Path -print -warn -amin Timespan',
#  'find Path -inum Timespan -fprint0 File -size Timespan',
#  'find Path -nouser -mount -xdev',
#  'find Path -nouser -links Timespan -used Timespan',
#  'find Path -writable -group Timespan -path Regex',
#  'find Path -version -help -size Timespan',
#  'find Path -depth -iregex Regex -print0',
#  'find Path -samefile File -atime Timespan -path Regex',
#  'find Path -nogroup -wholename Regex -noleaf',
#  'find Path -atime Timespan -ilname Regex -fprint File',
#  'find Path -ls -name Regex -ipath Regex',
#  'find Path -links Timespan -regex Regex -executable',
#  'find Path -links Timespan -prune -cmin Timespan',
#  'find Path -writable -noignore_readdir_race -lname Regex',
#  'find Path -d -regex Regex -fprint File',
#  'find Path -daystart -executable',
#  'find Path -nouser -version -used Timespan',
#  'find Path -version -noleaf -Olevel',
#  'find Path -daystart -mmin Timespan -user Timespan',
#  'find Path -name Regex -version -newerXY Timespan',
#  'find Path -writable -daystart -used Timespan',
#  'find Path -nogroup -samefile File -amin Timespan',
#  'find Path -daystart -fprint0 File -xdev',
#  'find Path -readable -d -size Timespan',
#  'find Path -delete -fprintf -fprint0 File',
#  'find Path -ipath Regex -regex Regex -group Timespan',
#  'find Path -version -mmin Timespan -follow',
#  'find Path -wholename Regex -regex Regex',
#  'find Path -daystart -cmin Timespan -path Regex',
#  'find Path -version -used Timespan -okdir',
#  'find Path -used Timespan -executable -print0',
#  'find Path -print -fprint File -follow',
#  'find Path -mmin Timespan -empty -amin Timespan',
#  'find Path -depth -iname Regex -user Timespan',
#  'find Path -iwholename Regex -writable -noleaf',
#  'find Path -nouser -depth -fls File',
#  'find Path -version -mtime Timespan -noleaf',
#  'find Path -version -readable -context Regex',
#  'find Path -ls -o -empty',
#  'find Path -mount -fprint0 File -true',
#  'find Path -inum Timespan -regex Regex -size Timespan',
#  'find Path -version -help -atime Timespan',
#  'find Path -inum Timespan -d -cmin Timespan',
#  'find Path -fls File -used Timespan',
#  'find Path -mtime Timespan -fls File -wholename Regex',
#  'find Path -version -samefile File -user Timespan',
#  'find Path -links Timespan -wholename Regex -true',
#  'find Path -o -version -mmin Timespan',
#  'find Path -depth -iname Regex -warn',
#  'find Path -iwholename Regex -quit -amin Timespan',
#  'find Path -ignore_readdir_race -samefile File -ilname Regex',
#  'find Path -readable -false -amin Timespan',
#  'find Path -writable -used Timespan -atime Timespan',
#  'find Path -nouser -iregex Regex -executable',
#  'find Path -name Regex -d -ilname Regex',
#  'find Path -nouser -nogroup -group Timespan',
#  'find Path -executable -ilname Regex -follow',
#  'find Path -ls -ignore_readdir_race -group Timespan',
#  'find Path -name Regex -o -fprint0 File',
#  'find Path -iwholename Regex -regex Regex -empty',
#  'find Path -version -wholename Regex -help',
#  'find Path -ipath Regex -prune -daystart',
#  'find Path -lname Regex -fprint0 File -print0',
#  'find Path -samefile File -fprint File -true',
#  'find Path -depth -noignore_readdir_race -help',
#  'find Path -regex Regex -fprint0 File -size Timespan',
#  'find Path -help -fprintf -samefile File',
#  'find Path -writable -ctime Timespan -group Timespan',
#  'find Path -mmin Timespan -fprintf -user Timespan',
#  'find Path -quit -ctime Timespan -follow',
#  'find Path -or -version -follow',
#  'find Path -nogroup -ctime Timespan -mmin Timespan',
#  'find Path -nouser -regex Regex -group Timespan',
#  'find Path -prune -d -noignore_readdir_race',
#  'find Path -noignore_readdir_race -regex Regex -used Timespan',
#  'find Path -ipath Regex -prune -amin Timespan',
#  'find Path -version -P -fprint0 File',
#  'find Path -ctime Timespan -help -true',
#  'find Path -ctime Timespan -used Timespan -size Timespan',
#  'find Path -iwholename Regex -mtime Timespan -delete',
#  'find Path -nogroup -amin Timespan',
#  'find Path -name Regex -iwholename Regex -false',
#  'find Path -name Regex -or -mmin Timespan',
#  'find Path -d -noignore_readdir_race -path Regex',
#  'find Path -nouser -delete -user Timespan',
#  'find Path -o -help -fprint File',
#  'find Path -nogroup -mtime Timespan -fprint0 File',
#  'find Path -prune -daystart -samefile File',
#  'find Path -atime Timespan -cmin Timespan',
#  'find Path -quit -inum Timespan -daystart',
#  'find Path -writable -depth -executable',
#  'find Path -name Regex -regex Regex -used Timespan',
#  'find Path -nouser -fprintf -size Timespan',
#  'find Path -ls -iname Regex -true',
#  'find Path -fls File -noleaf -path Regex',
#  'find Path -links Timespan -help -fprint File',
#  'find Path -nogroup -regex Regex -atime Timespan',
#  'find Path -version -mmin Timespan -fprint File',
#  'find Path -mtime Timespan -fprint File -amin Timespan',
#  'find Path -wholename Regex -samefile File -follow',
#  'find Path -writable -warn -amin Timespan',
#  'find Path -d -delete -regex Regex',
#  'find Path -mtime Timespan -noignore_readdir_race -follow',
#  'find Path -name Regex -user Timespan -xdev',
#  'find Path -ipath Regex -atime Timespan -executable',
#  'find Path -iregex Regex -d -executable',
#  'find Path -quit -group Timespan -fprint0 File',
#  'find Path -lname Regex -group Timespan -atime Timespan',
#  'find Path -writable -daystart',
#  'find Path -ipath Regex -ignore_readdir_race -xdev',
#  'find Path -readable -mtime Timespan -mmin Timespan',
#  'find Path -iwholename Regex -inum Timespan -fprint File',
#  'find Path -prune -d -help',
#  'find Path -version -prune -xdev',
#  'find Path -version -Olevel -cmin Timespan',
#  'find Path -ignore_readdir_race -mount -xdev',
#  'find Path -fls File -atime Timespan -executable',
#  'find Path -ignore_readdir_race -mmin Timespan -empty',
#  'find Path -d -noignore_readdir_race -warn',
#  'find Path -writable -iname Regex -noleaf',
#  'find Path -executable -fprint0 File -print0',
#  'find Path -name Regex -inum Timespan -amin Timespan',
#  'find Path -ls -iwholename Regex -noignore_readdir_race',
#  'find Path -noleaf -print0',
#  'find Path -ls -inum Timespan -warn',
#  'find Path -or -help -size Timespan',
#  'find Path -noleaf -ilname Regex -path Regex',
#  'find Path -print -or -lname Regex',
#  'find Path -writable -mtime Timespan -path Regex',
#  'find Path -nouser -noleaf -regex Regex',
#  'find Path -version -lname Regex -gid',
#  'find Path -iwholename Regex -nouser -delete',
#  'find Path -group Timespan -size Timespan -false',
#  'find Path -ls -print -executable',
#  'find Path -version -ipath Regex -ctime Timespan',
#  'find Path -help -mount -false',
#  'find Path -version -lname Regex -warn',
#  'find Path -quit -mtime Timespan -regex Regex',
#  'find Path -prune -noignore_readdir_race -cmin Timespan',
#  'find Path -warn -atime Timespan -fprint File',
#  'find Path -nouser -group Timespan -user Timespan',
#  'find Path -iregex Regex -help -path Regex',
#  'find Path -writable -ignore_readdir_race -mmin Timespan',
#  'find Path -or -version -O',
#  'find Path -ls -lname Regex -xdev',
#  'find Path -d -user Timespan -true',
#  'find Path -nouser -links Timespan -amin Timespan',
#  'find Path -ignore_readdir_race -regex Regex -used Timespan',
#  'find Path -ipath Regex -fls File -iregex Regex',
#  'find Path -ignore_readdir_race -warn -cmin Timespan',
#  'find Path -d -samefile File -true',
#  'find Path -group Timespan -mount -fprint0 File',
#  'find Path -noignore_readdir_race -mount -path Regex',
#  'find Path -print -depth -fprint0 File',
#  'find Path -name Regex -nouser -mount',
#  'find Path -ctime Timespan -delete -user Timespan',
#  'find Path -quit -nogroup -path Regex',
#  'find Path -ipath Regex -depth -executable',
#  'find Path -nogroup -mmin Timespan',
#  'find Path -group Timespan -size Timespan -path Regex',
#  'find Path -fls File -print0 -fprint File',
#  'find Path -writable -samefile File -atime Timespan',
#  'find Path -nogroup -ctime Timespan -size Timespan',
#  'find Path -ls -help -O',
#  'find Path -mmin Timespan -executable -follow',
#  'find Path -samefile File -executable -path Regex',
#  'find Path -fls File -mmin Timespan -xdev',
#  'find Path -quit -iname Regex -group Timespan',
#  'find Path -links Timespan -help -mount',
#  'find Path -links Timespan -daystart -warn',
#  'find Path -quit -ctime Timespan -mmin Timespan',
#  'find Path -iwholename Regex -ipath Regex -size Timespan',
#  'find Path -nouser -delete -mmin Timespan',
#  'find Path -version -gid -cmin Timespan',
#  'find Path -d -atime Timespan -ilname Regex',
#  'find Path -version -d',
#  'find Path -name Regex -empty -size Timespan',
#  'find Path -mtime Timespan -ilname Regex -size Timespan',
#  'find Path -prune -mount -follow',
#  'find Path -mtime Timespan -prune -used Timespan',
#  ...]

# %%
with open('generic_training2.txt', 'w') as fp:
    fp.write('\n'.join(ret))
