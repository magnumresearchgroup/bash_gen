# %% [markdown]
# # Verified Commands: Weighting to Match Training Data
#
# Running the scraping, generation, and verification pipeline to generate a bash command dataset, matching the utility distributions of the training dataset.

# %%
from generator import Generator, replace
from scraper import WebScraper
import collections

# %% [markdown]
# ## Reading the Training Data and Measuring the Distribution
#
# First, measuring the distribution of the training data/

# %%
with open('cmds_proccess_train.txt') as fp:
    txt = fp.read()
    
txt = txt.split('\n')
txt
# Out:
# ['find Path -type d ! -perm -Permission',
#  'find Path -type d -name Regex -execdir tar -c -v -f File File \\;',
#  'find Path -user Regex',
#  'find Path -name Regex -delete',
#  'find Path -name Regex',
#  'date -u -d @1267619929',
#  'find Path -group Regex',
#  'find Path -type d -exec chmod Permission {} +',
#  'find Path -type f -print0 | xargs -r -0 -I {} grep -F Regex {}',
#  'find Path -name Regex | xargs -I {} grep -r Regex {}',
#  'find Path Path Path Path',
#  'find Path -type f -name Regex',
#  'zcat Regex | grep -i Regex',
#  'zcat Regex | head -n Quantity',
#  'fold File | wc -l',
#  'find Path -print0 | xargs -0 -I {} echo {}',
#  'find Path -type d -name Regex -exec rsync -a -v -R {} File \\; -exec rm -r -f File \\;',
#  'cd $( find Path -name Regex | xargs -I {} dirname {} )',
#  'set | grep Regex',
#  'read -r -p $( echo Regex ) Regex',
#  'tree Directory',
#  'kill -s Regex Regex',
#  "date '+%Y' --date Regex",
#  'find Path -mmin -Quantity',
#  'find Path -type f -exec bzip2 {} \\;',
#  'find Path -name Regex -type f -exec wc -l File \\;',
#  'find Path -type c',
#  'find Path -name Regex -prune -or -print',
#  'read -e -p Regex Regex',
#  'find Path -nouser -exec rm File \\;',
#  'who | wc -l',
#  'ls -t -p | grep -v Regex | tail -n +Quantity | xargs -I {} rm -- {}',
#  'find Path -name Regex -exec grep Regex {} \\;',
#  'find Path -type f ! -perm Permission | head',
#  'read -p Regex Regex',
#  'ls -t -p | grep -v Regex | tail -n +Quantity | xargs -d Regex -I {} rm -- {}',
#  'df -H --total File',
#  'history | sed Program',
#  'find Path -xdev -print0',
#  'chown Regex File -R',
#  'find Path -depth -name Regex -exec rm -f -r {} \\;',
#  'who | cut -d Regex -f Number | sort | uniq',
#  'watch -n Quantity ps -C java -o pcpu,state,cputime,etimes',
#  'find Path -name Regex -exec grep -r Regex {} \\;',
#  'find Path -type f -name Regex | head - Quantity',
#  "date --date Regex '+%a'",
#  'find Path -mtime -Timespan',
#  'find Path -name Regex -execdir diff -u {} File \\;',
#  'ln -s File Regex',
#  'find Path | xargs -I {} grep Regex {}',
#  "find Path -maxdepth Quantity -mindepth Quantity -type d -printf '%f\\n'",
#  'seq Number | xargs -I {} echo {}',
#  'chown Regex -R File',
#  'find Path -name Regex',
#  'find Path -name Regex -exec grep -H Regex {} \\;',
#  'who -b',
#  'find Path -name Regex -exec chmod Permission {} \\;',
#  'find Path -type f -iname Regex -exec ls -l -r -t {} \\; | awk -F Regex Program',
#  'find Path -maxdepth Quantity -name Regex | tail',
#  'cut -d Regex -f Number File | xargs -n Quantity -I {} dirname {}',
#  'find Path -regex Regex',
#  'find Path -exec echo {} +',
#  'head -c Quantity File | tr Regex Regex',
#  'find Path -name Regex | xargs -I {} rm {}',
#  'mv $( ls ) File',
#  'find Path -type f -size +Size -print0 | xargs -0 -I {} rm {}',
#  'find Path -type f | sed -e Program | sed -e Program | sort | uniq -c | sort -r -n',
#  'read -N Quantity Regex',
#  'sort -n File',
#  'find Path -type f -exec chmod Permission {} +',
#  'find Path | grep -v Regex | sort',
#  'find Path -perm -Permission -type f -exec ls -l {} \\;',
#  'ls -d File',
#  'find Path -name Regex -type f -print0 | xargs -0 -I {} cp -u -t File {}',
#  'shopt -s nocaseglob',
#  'pushd',
#  'find Path -size +Size -size -Size',
#  'find Path -type d -exec chmod Permission {} +',
#  'find Path -type f -print0 | xargs -0 -n Quantity -I {} md5sum {} | sort -k Number | uniq -w Quantity -d --all-repeated separate | sed -e Program',
#  'find Path -name Regex -ls',
#  'find Path -type d -empty -exec rmdir -v -p --ignore-fail-on-non-empty {} +',
#  'readlink -e -v File',
#  'find Path -maxdepth Quantity -type f -iname Regex -printf ".\\n" | wc -l',
#  'find Path -iname Regex -type f -exec sed Program -i Regex {} \\; -exec rm File \\;',
#  'mkdir -p Directory',
#  'find Path -name Regex',
#  'w | tr -s Regex | cut -d Regex -f Number | tail -n +Quantity',
#  'find Path -mtime Timespan',
#  'find Path -maxdepth Quantity -name Regex -maxdepth Quantity | xargs -n Quantity -I {} rm {}',
#  'find Path -name Regex',
#  'find Path -name Regex',
#  'find Path -name Regex -exec grep -I -w Regex {} + | grep -E -v Regex',
#  'find Path -name Regex',
#  'find Path -name Regex',
#  'find Path -name Regex -exec sed -i Program {} +',
#  'rsync -a -v -z -r -u --delete-excluded File File',
#  'find Path -iname Regex -print',
#  'find Path -name Regex -exec mv -t Directory {} +',
#  'find Path -cmin Quantity -print',
#  'which Regex',
#  'file -b -i File',
#  'find Path \\( -name Regex -or -name Regex \\) -type f -ls',
#  'sed -z Program',
#  'find Path -name Regex -exec rm -r -f {} \\;',
#  'tac File | awk Program',
#  'chown $( whoami ) File',
#  'find Path -iname Regex',
#  'find Path -type d -exec chmod Permission {} \\;',
#  'echo Regex | grep -E -o Regex',
#  'find Path Path',
#  'find Path -path Regex -prune -or -iname Regex -print',
#  'echo Regex | grep -o -E Regex | cut -c Number | rev | cut -c Number | rev',
#  'echo $( seq Number Number )',
#  'crontab -l | awk Program',
#  'ssh -f Regex -L Regex -N',
#  'find Path -mtime +Timespan',
#  'ifconfig Regex | awk Program',
#  'find Path -name Regex -exec grep -i Regex {} \\;',
#  'find Path -type f -iname Regex -exec chmod Permission {} \\;',
#  'find Path -type d -size Size -print | xargs -I {} rmdir {}',
#  'awk Program Program | split -d -a Quantity -l Quantity File Regex',
#  'find Path -name Regex -print0 | xargs -0 -I {} rm {}',
#  'find Path -exec grep Regex {} +',
#  'cat File | rev | cut -d Regex -f -Number | rev',
#  'find Path -type f -exec grep Regex File {} \\; | wc --bytes',
#  'history | awk Program',
#  'find Path -path Regex -type f | xargs -I {} grep -l Regex {}',
#  'find Path | grep -E Regex',
#  'od -A n -t d -N File File',
#  'find -L Path -maxdepth Quantity -type l',
#  'false',
#  'find Path -type f -ls',
#  'rmdir --ignore-fail-on-non-empty Directory',
#  'mkdir Directory',
#  'mkdir -p Directory',
#  'find Path -amin -Quantity',
#  'find Path -name Regex -print',
#  'find Path -type f -printf "f %s %p\\n"',
#  'find Path -maxdepth Quantity -type f ! -name Regex -exec gzip {} \\;',
#  'dirname -- Regex',
#  "find Path -type f -iname Regex -printf '%h\\n' | sort | uniq | xargs -n Quantity -d Regex -I {} echo Regex Regex Regex",
#  'find Path -maxdepth Quantity -type f',
#  'chown Regex File -R',
#  'find Path -mmin Quantity -print',
#  'find Path -mindepth Quantity -maxdepth Quantity -type d | grep Regex | tr Regex Regex | xargs -0 -I {} ln -s -t Directory {}',
#  'find Path \\( -name Regex -or -name Regex -or -size +Size \\)',
#  'dig Regex Regex SRV',
#  'find Path -exec echo {} +',
#  'rsync -a -v -e File File File',
#  'find Path -exec grep Regex {} \\;',
#  'find Path -mindepth Quantity -exec mv {} --target-directory Directory \\;',
#  'rsync -r -v -z -e ssh -p Regex --progress File File',
#  'find Path',
#  'find Path -type l',
#  'find Path -fstype nfs -print',
#  'rsync File File',
#  'find Path -size +Size -ls',
#  'find Path -name Regex | xargs -I {} cat {} | wc -l',
#  'find Path -type d -name Regex',
#  'find Path -type d -print0',
#  'find Path ! \\( -name Regex -or -name Regex \\)',
#  'chown $( whoami ) File -R',
#  'find Path -exec grep -q Regex {} \\; -print',
#  'find Path -name Regex -exec grep Regex {} \\;',
#  'find Path -type f | xargs -I {} ls -l -t -r {} | tail -n Quantity',
#  'find Path -type f -exec chmod Permission {} \\;',
#  'find Path -name Regex -exec echo Regex Regex {} Regex \\;',
#  'find Path -type d -name Regex -print0 | xargs -0 -I {} rm -r -f {}',
#  'ps -e -f',
#  'rsync -a -v -R File File',
#  'comm -1 -2 <( sort File ) <( sort File ) | wc -l',
#  'date hostname echo Regex | sed Program | tr Regex Regex',
#  'find Path -type f -mtime +Timespan -print0 | xargs -0 -I {} rm {}',
#  'seq Number | xargs -P Quantity -I {} echo {}',
#  'find Path -type f -exec grep Regex {} \\;',
#  'cat File | tail -n +Quantity | split --lines Quantity',
#  'find Path -name Regex -prune -or -type f',
#  'jobs -p | awk Program',
#  'grep -E -o Regex File | tr Regex Regex',
#  'find Path -type d -name Regex -prune -or -print',
#  'source $( dirname Regex )',
#  'find Path -name Regex -exec grep Regex {} \\; -print',
#  'echo Regex | rev | cut -d Regex -f Number | rev',
#  'join -1 Regex -2 Regex -a Quantity <( cat -n File | sort -k Number ) <( sort File ) | sort -k Number | cut --complement -d Regex -f Number',
#  'find Path -name Regex -print -exec grep Regex {} \\;',
#  'rsync -a -q -z File File',
#  'find Path -name Regex -exec grep -r Regex {} \\;',
#  'cat File | grep -i Regex | more',
#  'hostname -I | awk Program',
#  'find Path -mindepth Quantity -printf "%T@ %P\\n" | sort -n -r | cut -d Regex -f Number | tail -n +Quantity',
#  'read -s -N Quantity Regex',
#  'du -h --max-depth Quantity File | sort -n -r',
#  'gzip -d -c Regex | grep -P --regexp Regex | split -d -l Quantity File Regex',
#  'cat -n File | less',
#  'find Path -maxdepth Quantity -not -iname Regex',
#  'ls -a -l -F -t $( find Path -name Regex ) | rev | cut -d Regex -f Number | rev | head - Quantity',
#  'find Path -type d -print0 | xargs -0 -I {} chmod Permission {}',
#  'find Path -mmin Quantity',
#  'find Path -type f -print | grep -E -i Regex',
#  'find Path -name Regex',
#  'find Path -name Regex -print0 | xargs -0 -I {} rm -r -f {}',
#  'find Path -name Regex',
#  'zcat Regex | sed -n Program',
#  'mktemp -d',
#  'find Path \\( -name Regex -and \\( -name Regex -or -name Regex \\) \\) -delete',
#  'find Path -name Regex -or -name Regex',
#  'fold -w Quantity File',
#  'find Path -type d -name Regex | xargs -n Quantity -I {} cp File {}',
#  'find Path -maxdepth Quantity -type d -iname Regex -exec cp -r {} File \\;',
#  'find Path -type f -iname Regex -daystart -mtime Timespan -exec cp {} File File \\;',
#  'find Path -name Regex',
#  'find Path -depth -name Regex -prune -or -print0 | cpio -0 -p -d -v --quiet Regex',
#  'mkdir Directory',
#  'find Path -type f -iname Regex ! -path Regex -or -iname Regex ! -path Regex',
#  'find Path -type d -name Regex | sort -r',
#  'find Path -ctime -Timespan | cpio -p -v -d -m Regex',
#  'find Path -type f -mmin -Quantity',
#  'find Path -name Regex -exec rm {} \\;',
#  'find Path -mtime +Timespan -mtime -Timespan',
#  'find Path -type f -ctime -Timespan | tail -n Quantity',
#  'find Path -name Regex -type f -daystart -mtime +Timespan | xargs -I {} rm -f {}',
#  'chmod +Permission $( which Regex )',
#  'ssh -f Regex -L Regex -N',
#  'find Path -name Regex -type f',
#  'cat File | tail -n +Quantity | split --lines Quantity',
#  'echo Regex',
#  'basename Regex',
#  'find Path -type f -atime -Timespan',
#  'find Path -name Regex | xargs -I {} rm {}',
#  'echo Regex | cut -d Regex -f Number',
#  'find Path -ctime -Timespan -print',
#  'find Path -path Regex -print',
#  'find Path -maxdepth Quantity -type f -regex Regex -not -name Regex',
#  'find Path -name Regex | xargs -I {} grep -E Regex {}',
#  'tr -c -s Regex',
#  'cd $( dirname Regex )',
#  'find Path -name Regex -exec rename Regex Regex \\;',
#  'find Path -type f -exec chmod Permission {} + -or -type d -exec chmod Permission {} +',
#  'find Path -type d -perm Permission -print -exec chmod Permission {} \\;',
#  'find Path -type f | sed -e Program | sort | uniq',
#  'find Path -name Regex -execdir diff -u {} File \\;',
#  'find Path -type f -mtime +Timespan',
#  'find Path -empty -delete -print',
#  'ifconfig | grep Regex',
#  'find Path -name Regex',
#  'find Path -type f -exec ls -a -l {} \\; | sort -n -r -k Number | head -n Quantity',
#  'find Path -type f -name Regex -exec rm {} \\;',
#  'find Path -type f ! -perm Permission',
#  'find Path -name Regex -print | xargs -I {} rm {}',
#  'find Path -type f -size +Size -exec ls -l -h {} \\; | awk Program',
#  'find Path -type f -exec chmod Permission {} \\;',
#  'su -l Regex',
#  'grep Regex File | wc -l',
#  'find Path -group Regex -print | xargs -I {} chown Regex {}',
#  'du -a',
#  'basename $( echo Regex | tr Regex Regex )',
#  "find Path -type f -printf '%T@ %p\\n' | sort -n -r | head - Quantity | cut -f Number -d Regex | sed -e Program | xargs -I {} ls -U -l {}",
#  'cat File | more',
#  'find Path -name Regex -delete',
#  'find Path -name Regex',
#  'read Regex',
#  'find Path -size +Size',
#  'split -n Quantity File',
#  'sort --merge File | split -l Quantity File Regex',
#  'find Path -name Regex -and -size +Size',
#  'ssh -p Regex Regex',
#  'find | wc -l',
#  'mkdir -p Directory',
#  'mktemp -p Directory -d Regex',
#  'rsync -a -v --ignore-existing File File',
#  'find Path -type f -name Regex -exec ls -l {} \\;',
#  'find Path -name Regex -print0',
#  'find Path -print -name Regex -prune',
#  'mkdir Directory',
#  'cat File | sort --unique | wc -l',
#  'find Path -type l -name Regex -ls',
#  'readlink -m File',
#  'find Path -depth -name Regex -exec rm -r -f {} \\;',
#  'find Path -type f -name Regex',
#  'find Path -mtime Timespan -exec du -k -s {} \\; | cut -f Number',
#  'read -p Regex',
#  'echo -e $( echo -n -e Regex | wc -m )',
#  'find Path -name Regex -exec grep Regex File {} +',
#  'find Path -type f \\( -name Regex -or -name Regex -or -name Regex \\)',
#  'ping -c Quantity -b Regex | sed -n Program | sort | uniq',
#  'seq Number Number | awk Program',
#  'find Path -type f -name Regex',
#  'find Path -iname Regex | xargs -I {} grep Regex {}',
#  'find Path -print | xargs -I {} ls {}',
#  'find Path -size +Size -ls',
#  'find Path -type l -xtype l',
#  'dig -x Regex | awk Program',
#  'find Path -newer File -user Regex -print',
#  'comm -2 -3 <( find Path -type f | sed Program | sort ) <( find Path -type f | sed Program | sort ) | sed Program',
#  'find Path -name Regex | xargs -I {} grep -v -c Regex {} | awk Program',
#  'find Path -type f -name Regex',
#  'mkdir Directory Directory Directory Directory Directory',
#  'cat -v File',
#  'find Path -name Regex -exec cp -a {} File \\;',
#  'find Path -name Regex -print0 | xargs -0 -I {} cp {} File',
#  'find Path -type f -print0 | xargs -0 -I {} grep -c -H Regex {} | awk -F Regex Program',
#  'find Path -exec grep Regex {} \\;',
#  'find Path -inum Quantity -exec ls -l {} \\;',
#  'du -c -s -x -b File | md5sum -c File',
#  'find Path -name Regex',
#  'find Path -type f -exec sed -i Program {} \\;',
#  'mktemp -t Regex',
#  'find Path -type f -print0 | tr Regex Regex',
#  'find Path -type f -iname Regex -ls',
#  'find Path -type f -iname Regex -exec grep -s Regex {} \\;',
#  'find Path -type f | xargs -I {} grep Regex {}',
#  'cat File | xargs -n Quantity -I {} cp File {}',
#  'find Path -type f -exec chmod Permission {} \\;',
#  'find Path -mindepth Quantity -delete',
#  'find Path -type d -mindepth Quantity -print0',
#  'tail -f Regex | grep --line-buffered Regex | grep Regex',
#  'find Path -mtime +Timespan | xargs -I {} tar -c -z -v -P -f $( date +%F ) {}',
#  'find Path -type f -name Regex',
#  'find Path -size +Size',
#  'echo Regex | md5sum',
#  'find Path -user Regex | head',
#  'find Path -type f -print0 | xargs -0 -I {} grep -I -Z -l Regex {} | xargs -0 -I {} grep Regex {}',
#  'echo Regex | rev | cut -c Number | rev',
#  'find Path -name Regex -print0 | xargs -0 -I {} grep -H Regex {}',
#  'date -d Regex',
#  'find Path -type d -exec chmod Permission {} \\;',
#  'find Path -type f -name Regex | cut -c Number | nl',
#  'find Path -type f -name Regex -size +Size -exec rm -i {} \\;',
#  'find Path -type d -iname Regex -ls',
#  'find Path -name Regex | grep -v Regex | grep -v Regex | grep -v Regex',
#  'find Path -daystart -atime Timespan',
#  'find Path -name Regex | xargs -I {} grep -E Regex {}',
#  'ls | xargs -I {} mv {} File',
#  'join -1 Regex -2 Regex -t Regex File File',
#  'mv File File',
#  'rmdir $( dirname $( dirname Regex ) )',
#  'cd $( find Path -name Regex | xargs -I {} dirname {} )',
#  'shopt -s extglob progcomp',
#  'echo $( pwd )',
#  '$( date "+%s:%N" )',
#  'find Path -type f -exec grep Regex {} \\;',
#  'date --date Regex +"%d"',
#  'mkdir Directory',
#  'find Path -name Regex -type d | rename Regex',
#  'echo $( date )',
#  'mkdir Directory',
#  'find Path -name Regex | xargs -i -I {} rm -r -f {} {}',
#  'cat File | tr -s Regex | cut -d Regex -f Number',
#  'split --help',
#  'find Path ! \\( -name Regex -or -name Regex \\) {} Path -print',
#  'find Path -type f -name Regex',
#  'find Path -xdev -type f -size +Size -name Regex -exec gzip -v {} \\;',
#  'find Path -name Regex',
#  'find Path -depth -type d | sed Program',
#  'find Path -type f -print0 | xargs -0 -I {} chmod Permission {}',
#  'cat File | paste -d Regex File File',
#  'readlink -f File',
#  'cut -d Regex -f Number File | paste -d Regex -s',
#  'find Path -name Regex -exec ls {} \\;',
#  'find Path -type d -maxdepth Quantity -empty -delete',
#  'mkdir -p Directory',
#  'find Path -mmin -Quantity',
#  'find Path ! -name Regex | grep Regex',
#  'find Path -perm Permission | head',
#  'readlink -f $( which Regex )',
#  'set -- $( cal DateTime DateTime )',
#  'dirname Regex',
#  'split -n Quantity File',
#  'find | grep -E Regex',
#  'find Path -name Regex -maxdepth Quantity -print0 | xargs -0 -I {} mv {} File',
#  'finger | sed Program | sed Program | awk Program | sort | uniq',
#  'find Path -mtime Timespan -type f -ls',
#  'find Path -mtime -Timespan -type f -print0 | xargs -0 -I {} tar -r -v -f File {}',
#  'ls -F -l -t -r',
#  'find Path -user Regex',
#  'find Path -name Regex -ls | awk Program',
#  'find Path -type d -exec ls -d -l -r -t {} \\; | wc --lines',
#  'echo Regex | awk Program',
#  'find Path -name Regex -print0',
#  'split File Regex',
#  'find Path -type d -name Regex -exec chmod Permission {} \\;',
#  'find Path -type d -exec chmod Permission {} +',
#  'cat File | xargs -I {} du -c {} | tail - Quantity | awk Program',
#  'find Path -perm Permission -type f | sed Program | sort | diff -u Quantity File',
#  'mkdir Directory',
#  'find Path \\( -name Regex -or -name Regex \\) -prune -or -name Regex -type f -print',
#  'find Path -type f -perm Permission -print -exec chmod Permission {} \\;',
#  'find Path -iname Regex -type f',
#  'find Path -mtime -Timespan',
#  'mv File $( ls File | rev | cut -c Number | rev )',
#  'find Path -mtime -Timespan ! -name Regex -type f -exec basename {} \\;',
#  'join -j Regex -o 2.1,2.2,1.2,1.3 <( sort File ) <( sort File )',
#  'echo -e $( echo -n -e Regex | wc -m )',
#  'comm -3 File File',
#  'read -p Regex',
#  'find Path -daystart -mtime -Timespan -type f ! -mtime -Timespan -exec ls -l -d {} \\;',
#  'find Path -nouser',
#  'find Path -type f -name Regex -exec sed Program File \\;',
#  'find Path -name Regex',
#  'find Path -print0 | grep -a -z -Z Regex | xargs -0 -I {} file {}',
#  'find Path Path Path -print | tee File',
#  'shopt -s -o nounset',
#  'find Path Path -name Regex',
#  'shopt -p | grep Regex',
#  'find Path -name Regex',
#  'cd $( dirname $( which Regex ) )',
#  'find Path -user Regex -perm -Permission',
#  'find Path -name Regex | xargs -0 -I {} ls {}',
#  'mkdir --parents Directory',
#  'find Path -uid Regex',
#  'find Path -type f -name Regex -print0 | xargs -0 -I {} cp -a {} File',
#  'find -L Path',
#  'grep $( dirname Regex ) File',
#  'find Path -name Regex -print0 | xargs -0 -I {} tar -u -f File {}',
#  'echo Regex | tee File',
#  'sort File File | uniq -d | wc -l',
#  'find Path -iname Regex -printf "%p %f\\n"',
#  'cat <( crontab -l ) <( echo Regex ) | crontab File',
#  'ps -A -o pid | xargs -I {} readlink File | xargs -I {} dirname Regex',
#  'find Path -maxdepth Quantity -print',
#  "date -d Regex '+%Y-%m-%d'",
#  'nl -n rz -w Quantity -s Regex File | sed Program File',
#  'find Path -name Regex -print | less',
#  'env | grep Regex',
#  'find -type d Path Path Path {} +',
#  'find Path -maxdepth Quantity -not -iwholename Regex',
#  'find Path -size +Size -iname Regex',
#  'cat File | cut -f Number -d Regex',
#  'find Path -name Regex -type f -exec chmod Permission {} \\;',
#  'mount -o ro,remount -t yaffs2 Regex Regex',
#  'find Path -name Regex',
#  'awk Program Program',
#  'find Path -name Regex',
#  'find Path -user Regex',
#  'find Path -type d -exec chmod Permission {} \\;',
#  'find Path -not \\( -name Regex -or -name Regex \\) {} Path -print',
#  'find Path -name Regex -type f -not -path Regex -print0 | xargs -0 -I {} cp -t Directory {}',
#  'du -a File | sort -n -r | head -n Quantity',
#  'ssh-keygen -f File -P Regex',
#  'mkdir -p Directory',
#  'find Path -nouser | xargs -I {} rm {}',
#  'grep Regex $( find Path )',
#  'find Path -type d -empty -exec rmdir -v -p --ignore-fail-on-non-empty {} +',
#  'ssh -R Regex Regex',
#  'find Path -name Regex -exec chmod Permission {} \\; -exec echo {} \\; | wc -l',
#  'cat File | grep -F -v -f Regex | grep Regex',
#  'read Regex',
#  'find Path -name Regex -print0 | xargs -0 -I {} rm {}',
#  'w | awk Program',
#  'source $( which Regex )',
#  'ssh -M -S Path -f -n -N -T -L Regex Regex',
#  'find Path -type d | grep -E -v Regex | less',
#  'echo $( groups Regex | sed -e Program -e Program )',
#  'pstree -a Regex',
#  'cat File | wc -l',
#  'find Path -name Regex -or -name Regex | xargs -I {} wc -l {}',
#  'ssh -L Regex Regex',
#  'find Path \\( -perm -Permission -or -perm -Permission \\) -ls',
#  'find Path -xtype l',
#  'echo Regex | cut -d Regex -f Number',
#  'find Path -name Regex',
#  'find Path -name Regex -exec grep Regex {} \\;',
#  'finger | awk Program',
#  'sed Program File | xargs -I {} mkdir -p {}',
#  'find Path -printf "%y %p\\n"',
#  "find Path -type f -mtime Timespan | xargs -I {} tar -c -v -f $( date '+%d%m%Y'_archive.tar ) {}",
#  'echo $( sed -e Program Program )',
#  'find Path',
#  'find Path -L -xtype l',
#  'find Path -exec gunzip -v -t {} +',
#  'find Path -name Regex',
#  'shopt -s globstar',
#  'find Path -type f | xargs | wc -c',
#  'yes Regex | nl | tee File',
#  'mkdir -p $( seq -s Regex Number )',
#  'shopt | grep Regex',
#  'find Path -name Regex -print0 | xargs -0 -I {} grep -H Regex {}',
#  'rsync -a -f Program -f Program File File',
#  'finger -l | awk Program | sed Program',
#  'find Path -type f -exec chmod Permission {} \\;',
#  'od -t x1 -A n File | head',
#  'find Path -name Regex | xargs -I {} ls -t -l {}',
#  'seq Number Number',
#  'cat File | sed Program',
#  'find Path -iname Regex',
#  'find Path -name Regex -exec grep Regex {} File \\;',
#  'find Path -name Regex -print0 | xargs -I {} -0 bzip2 -d -c {} | cut -f Number -d Regex',
#  'find Path -type f -printf "\\n%Ab %p" | head -n Quantity',
#  'pstree -p -s Regex',
#  'set -e',
#  'find Path -type f \\( -name Regex -or -name Regex \\) -exec wc -l {} +',
#  'find Path -cmin -Quantity | head',
#  'find Path',
#  'find Path | head',
#  'dig Regex Regex @resolver1.opendns.com',
#  'find Path -perm -Permission -print',
#  'find Path -size -Size',
#  'find Path -name Regex | xargs -I {} cp File {}',
#  'find Path -amin -Quantity',
#  'chown Regex -R File',
#  'find Path -atime +Timespan -exec rm {} \\;',
#  'source <( curl Regex Regex )',
#  'man Regex',
#  'find Path -type f -newerct Regex ! -newerct Regex',
#  'ls -1',
#  'rsync File File',
#  'find Path -name Regex',
#  'gunzip -c Regex | grep -f File | sort | uniq -c',
#  'find Path -perm Permission',
#  'find Path -type f -name Regex -exec rm -f {} \\;',
#  'rsync -a -v -z -r -u --delete-excluded File File',
#  'kill - Regex Regex',
#  'find Path -name Regex -exec rm -f {} \\;',
#  'paste -s -d Regex File',
#  'ls | xargs -n Quantity -I {} cp -i File {}',
#  'find Path | xargs -I {} grep Regex -l -s {}',
#  'find Path -name Regex | tr Regex Regex | xargs -0 -I {} rm {}',
#  'find Path -type f Path | grep -v Regex',
#  'cat File | md5sum',
#  'hostname -I',
#  'find Path -type f -exec sed -i Program {} \\;',
#  'find Path -type d -exec mkdir -p Directory \\; -or -type f -exec touch File \\;',
#  'find Path -type f -mtime +Timespan',
#  'chgrp Regex File',
#  'find Path -name Regex | sort | xargs -I {} wc -l {}',
#  'find Path -perm Permission',
#  'find Path -type f -name Regex -execdir mv {} File \\;',
#  'find Path -maxdepth Quantity -name Regex',
#  'find Path -name Regex',
#  'find Path -type f -name Regex -exec sed -i Program {} \\;',
#  'find Path -type f -iname Regex -print0 | xargs -0 -I {} grep Regex {}',
#  'find Path ! -path Regex',
#  'find Path -type f -regextype posix-extended \\( ! -regex Regex \\) -print0 | xargs -0 -I {} cp -p --target-directory Directory {}',
#  'mkdir -p Directory',
#  'find Path -xtype f ! -iname Regex -exec mv -i -v {} File \\;',
#  'find Path -regex Regex',
#  'find Path -type f -size +Size',
#  'find Path -type d -print',
#  'find Path -maxdepth Quantity -name Regex -print0 | xargs -0 -I {} zcat {} | awk -F Regex Program',
#  'find Path -iname Regex -type f -exec sed Program -i Regex {} \\; -exec rm File \\;',
#  'find Path -type f -print0 | xargs -0 -I {} rm {}',
#  'cal DateTime DateTime | sed -e Program -e Program -e Program',
#  'history | tail - Quantity | grep Regex',
#  'set | grep -E Regex | sed -r -e Program',
#  'find Path -type d -name Regex',
#  'find Path -type f | wc -l',
#  'ls $( pwd )',
#  'find Path -name Regex -exec grep --with-filename Regex {} \\;',
#  'find Path -type f -regex Regex | wc -l',
#  'find Path -name Regex | xargs -I {} cp -a --target-directory Directory --parents {}',
#  'find Path \\( -newer File -or -user Regex \\) -print',
#  'find Path -name Regex -print',
#  'find Path -xtype l',
#  'tail -n $( grep -n Regex File | head -n Quantity | cut -d Regex -f Number ) File',
#  'echo Regex | tee File',
#  'echo <( true )',
#  'find Path -type f -name Regex | xargs -I {} tar -c -v -f File File {}',
#  'find Path -name Regex -print0 | xargs -0 -I {} grep -E Regex {}',
#  'split -b Size File Regex',
#  'sed Program | rev | cut -d Regex -f Number | rev',
#  'echo Regex | tee File',
#  'find Path -type d | tr Regex Regex',
#  'ping -c Quantity Regex | tail - Quantity | awk Program | cut -d Regex -f Number',
#  'find Path | xargs -I {} file {}',
#  'find Path -name Regex | wc -l',
#  'find Path -name Regex | xargs -I {} rm -r -f {}',
#  'tree',
#  'cd Directory',
#  'file $( which Regex )',
#  'sort File | uniq -c',
#  'find Path -regextype posix-egrep -regex Regex',
#  'ls $( pwd )',
#  'find Path -name Regex -prune -or -print',
#  'echo $( whoami )',
#  'file File | grep Regex',
#  'find Path ! -path Regex -print',
#  'find Path -iname Regex ! -iname Regex',
#  'cd $( dirname $( which Regex ) )',
#  'find Path ! -user Regex -print0 | xargs -0',
#  'find Path -user Regex -name Regex',
#  'find Path -path Regex -print',
#  'find Path -depth -name Regex',
#  'set | grep -P Regex | grep -o -P Regex',
#  'mount Regex Regex -o loop -t vfat',
#  'find Path -ctime -Timespan -type f -printf "%P\\n" | xargs -I {} rsync -a -v -R File File',
#  'find Path -size +Size -exec ls -l -S {} + | head - Quantity',
#  'sed Program File | od -c',
#  'find Path Path -name Regex',
#  'find Path -type d -exec chown Regex {} \\;',
#  'find Path -mtime -Timespan -type f',
#  'set -o errexit',
#  'find Path Path -type d Path \\( -path Regex Path -or Path -name Regex Path \\) Path -prune Path -or Path -type f -name Regex -print',
#  'find Path -type f -exec du -S -h {} + | sort -r -h | head -n Quantity',
#  'echo Regex | od -A n -v -t x1 | tr -d Regex',
#  "find Path -name Regex -printf '%h\\n'",
#  'split -a Quantity -d -l Quantity File Regex',
#  'diff File <( sort File ) <( sort File )',
#  'find Path -newer File -print',
#  'chmod Permission -R File',
#  'find Path -mtime -Timespan -print0 | xargs -0 -I {} tar -r -f File {}',
#  'bind -p | grep Regex',
#  'find Path | grep Regex',
#  'find Path ! -user Regex',
#  'find Path -name Regex -type f -print0 | xargs -0 -I {} rm -i {}',
#  'find Path -depth -type d -empty -exec rmdir {} \\;',
#  'find Path -mindepth Quantity -maxdepth Quantity',
#  'cat File',
#  'split -l Quantity File Regex',
#  'find -x Path -inum Quantity',
#  'shopt -o extglob',
#  'kill $( jobs -l -p )',
#  'ls -l | grep Regex',
#  'read -p $( echo -e Regex ) Regex',
#  'find Path ! -name Regex',
#  'find Path Path -name Regex -or -name Regex',
#  'find Path -type d',
#  'ping -c Quantity Regex | head -n Quantity | grep -E -o -w Regex',
#  'grep -R -I -l Regex File',
#  'find Path -name Regex | xargs -s Quantity -I {} rename Regex {}',
#  'find Path -name Regex -print0 | xargs -0 -n Quantity -I {} dirname {} | sort | uniq',
#  'echo $( basename $( dirname $( dirname Regex ) ) )',
#  'readlink $( which Regex )',
#  'mkdir -p Directory',
#  'find Path -type f -print0 | xargs -0 -I {} grep -l -E Regex {}',
#  'split -b Size File Regex',
#  'find Path -type f -perm Permission -exec chmod Permission {} \\;',
#  'find Path -name Regex -print',
#  'gunzip -c Regex | tar -x -f File',
#  'find Path -maxdepth Quantity -name Regex -prune -or -print0 | xargs -0 -i -I {} cp {} File {}',
#  'find Path -type f -print0 | xargs -0 -I {} grep -I Regex {}',
#  'zcat Regex | tar -x -v -f File',
#  'find Path -name Regex | sed Program | xargs -n Quantity -I {} wget {}',
#  'awk Program <( rev File )',
#  'find Path -user Regex -or -user Regex',
#  'tar -c -v -f File $( find Path -iname Regex )',
#  'find Path -type f -print0 | xargs -r -0 -I {} grep -F Regex {}',
#  'find Path -name Regex | xargs -I {} grep Regex {}',
#  'find Path -name Regex | xargs -I {} cat {}',
#  'find Path -name Regex',
#  'chmod Permission File',
#  'find Path -type f -printf "%s %p\\n" | sort -r -n | head -n Quantity',
#  'echo $( find Path -type f -perm -Permission ) Regex Regex Regex Regex',
#  'find Path -size +Size -printf "%12s %t %h/%fn"',
#  'find Path -name Regex -exec rm -f {} \\;',
#  'find Path -name Regex -prune -or -mindepth Quantity -print',
#  'find Path -name Regex -exec echo {} \\;',
#  'find Path -type f -name Regex | xargs -I {} sed -i Program {}',
#  'find Path -type f -execdir sort -o File {} \\;',
#  'find Path -name Regex',
#  'find Path -maxdepth Quantity -type f -perm -Permission',
#  'rm -r File',
#  'read -t Quantity -n Quantity -r -p Regex Regex',
#  'find Path -daystart -mtime +Timespan -mtime -Timespan Path -printf "%M %n %u %g %10s %TY-%Tm-%Td %Ta %TH:%TM:%TS %h/%f\\n" | awk Program',
#  'find Path -iname Regex | grep -v Regex',
#  'tree -f -i | grep -v Regex',
#  'find Path -type d -empty -exec cp File {} \\;',
#  'find Path $( pwd ) -name Regex | xargs -l Quantity -I {} dirname {}',
#  'ls -t -p | grep -v Regex | tail -n +Quantity | xargs -I {} rm -- {}',
#  'find Path -type f -size +Size -exec ls -l -h {} \\; | awk Program',
#  'find Path -name Regex -exec zcat {} \\;',
#  'chown $( whoami ) File',
#  'echo Regex | cut -d Regex -f Number',
#  'find Path -type d -exec chmod Permission {} \\;',
#  'find Path -name Regex -exec rm {} \\;',
#  'find Path -newer File',
#  'find Path -name Regex',
#  'find Path -daystart -mtime -Timespan',
#  'find Path -size +Size -exec ls -l -h {} +',
#  'find Path -type d -maxdepth Quantity',
#  'chown Regex File',
#  'find Path -perm -Permission',
#  'split -a Quantity File',
#  'find Path -name Regex -type f -print0 | xargs -0 -I {} sed -i Program {}',
#  'find Path -type f -exec chown Regex {} \\;',
#  'find Path -type f -empty -print0 | xargs -0 -I {} rm {}',
#  'echo Regex | grep --only-matching Regex | xargs | tr --delete Regex',
#  'echo Regex $( pwd )',
#  'find Path -type d -and ! -name Regex -or -name Regex -and ! -prune',
#  'mkdir Directory',
#  'find Path \\( -name Regex -or -name Regex \\) -print',
#  'find Path -maxdepth Quantity -type d -mtime +Timespan -exec rm -r -f {} \\;',
#  'find Path -type d -exec chmod Permission {} \\;',
#  'cd Directory',
#  'find Path -empty',
#  'diff --brief <( awk Program Program ) <( tac File | awk Program )',
#  'find Path -path Regex -prune -or -nouser -or -nogroup',
#  'find Path -newermt Regex',
#  'find Path -name Regex',
#  'find Path -name Regex -print | grep -v Regex',
#  'sort --random-sort File | head -n Quantity',
#  'tac File | sed -e Program | tac | sed -e Program',
#  'find Path -mtime +Timespan',
#  'mount | sed -n -e Program',
#  'find Path -type f -iwholename Regex -exec grep -H Regex {} \\;',
#  'find Path -type f -name Regex -printf "cp \'%p\' \'/tmp/test_%f\'\\n" | bash',
#  'find Path -mmin Quantity -print0 | xargs -0 -r -I {} ls -l {}',
#  'find Path -name Regex',
#  'crontab File',
#  'cp -R File File',
#  'find Path -maxdepth Quantity -type f -exec md5sum {} \\; | awk Program',
#  'chown -R Regex File',
#  'crontab -l',
#  'find Path -type f -size -Size',
#  'find Path -exec chmod Permission {} \\;',
#  'grep -i -n -r Regex File',
#  'find Path -name Regex -print0 | xargs -r -0 -I {} grep -l Regex {}',
#  'find Path -mtime +Timespan -exec rm {} \\;',
#  'find Path -maxdepth Quantity -name Regex -exec rm -r {} \\;',
#  'find Path -iname Regex',
#  'touch -d $( date -r File ) File',
#  'find Path -name Regex -name Regex',
#  'find Path -iname Regex',
#  'find Path -type -f Path Path -print0 | xargs -0 -I {} ls -1 -h -s -S {}',
#  'find Path -perm Permission -type f -exec ls -l {} \\;',
#  'find Path -atime -Timespan',
#  'find Path -name Regex -exec grep -i -n Regex {} + | grep Regex | cut -d Regex -f Number | uniq',
#  'find Path -name Regex',
#  'echo Regex | rev | cut -d Regex -f Number | rev',
#  'find Path -type f -exec sed -i Program {} \\;',
#  'find Path -ctime Timespan -type f',
#  'find Path -exec echo {} +',
#  'find Path -type f -newermt Regex ! -newermt Regex -exec ls -l File \\;',
#  'cat --help',
#  'basename Regex',
#  'yes | cat -n | head - Quantity | awk Program',
#  'find Path -maxdepth Quantity -type d -print | wc -l',
#  'find Path -print | xargs -I {} grep Regex {}',
#  'finger -l | grep Regex | cut -d Regex -f Number | cut -c Number | sort | uniq',
#  'find Path -amin -Quantity -type f',
#  'split -b Size -d -a Quantity File Regex',
#  'find Path -name Regex -exec grep Regex {} \\; -print',
#  'grep Regex File File',
#  'find Path -type f -exec cat {} \\; | tr -c Regex Regex | grep Regex',
#  'find Path -depth -type d -mtime Timespan -exec mv -t Directory {} +',
#  'find Path -size +Size -name Regex -print0 | xargs -0 -I {} ls -l -S -h {}',
#  'scp -q -v File File',
#  'read -s Regex',
#  "find Path -type f -printf '%T@ %p\\n' | sort -n | tail - Quantity | cut -f Number -d Regex",
#  'find Path $( pwd ) -name Regex -exec dirname {} \\;',
#  'find Path -name Regex | grep -v Regex | grep -v Regex',
#  'find Path -prune -newer File',
#  'find Path -mindepth Quantity -delete',
#  'find Path -type d -name Regex -ok cp File {} \\;',
#  'echo Regex | sed Program',
#  'find Path -type f -mtime +Timespan -printf "%h\\n" | sort | uniq',
#  'find Path | head',
#  'false true',
#  'find Path -type d -name Regex',
#  'find Path -name Regex -print',
#  'find Path',
#  'echo -e Regex | awk Program | od -a',
#  'find Path -xdev -samefile Regex -exec rm {} +',
#  'find Path -daystart -mtime Timespan',
#  'find Path -type f -print0',
#  'find Path -type f \\( -name Regex -or -name Regex \\) -print0 | xargs --null -I {} grep --with-filename --line-number --no-messages --color --ignore-case Regex {}',
#  "find Path -type -f -mtime Timespan -exec rm {} \\; -printf '.' | wc -c",
#  'find Path -name Regex -exec  \\; -print',
#  'find Path -mindepth Quantity -type d -empty -delete',
#  'date -u -d Regex',
#  'find Path -type f -exec touch {} +',
#  'grep -F --include Regex -r -l Regex | xargs -L Quantity -I {} dirname {}',
#  'ssh -X Regex',
#  'find Path -type f -name Regex -exec rm {} \\;',
#  'find Path -type f',
#  'readlink -f $( which Regex ) | sed Program',
#  'chmod Permission $( find Path -type f )',
#  'find Path -name Regex -exec grep Regex {} \\; -print',
#  "date -d Regex +'%Y-%m-%d %H:%M:%S'",
#  'mkdir -p Directory',
#  'find Path -name Regex',
#  'tac File | sed Program | tac',
#  'file File | grep Regex',
#  'ls -t | head -n Quantity',
#  'find Path -type f | xargs -I {} grep Regex {}',
#  'cat File | nl',
#  'find Path -name Regex | sed Program | xargs -i -I {} echo Regex Regex Regex {} | sh',
#  'ln -s File',
#  'mv File File',
#  'bzip2 -t File',
#  'tail -n Quantity File',
#  'find Path -type f -follow | xargs -I {} ls -a -l {} | awk Program | sort -u',
#  'ln File -s',
#  'find Path -mindepth Quantity -name Regex',
#  "find Path -type f -printf '%s\\n' | awk Program",
#  'find Path -name Regex -prune -or -depth Path -print',
#  'ls $( which Regex ) -a -l',
#  'find Path -perm Permission',
#  'find Path -name Regex',
#  'find Path -newermt Regex',
#  'diff File File -r -x Regex',
#  'find Path -name Regex -print0 | xargs -0 -I {} rm {}',
#  'find Path -amin -Quantity',
#  'find Path -name Regex',
#  'ls -l | grep Regex | awk -F Regex Program',
#  'tree --help | head -n Quantity',
#  'find Path -type f -name Regex -exec rm -f {} \\;',
#  'su Regex',
#  'find Path -type f -exec grep -l Regex {} \\; -exec file {} \\; | grep Regex',
#  'find Path -type f -print0 | xargs -0 -I {} chmod Permission {}',
#  'dig Regex Regex "$domain" | wc -l',
#  'find Path -name Regex ! -name Regex -prune',
#  'which -a Regex | wc -l',
#  'find Path -printf "%T@ %p\\n" | sort -n | head - Quantity | cut -d Regex -f Number | xargs -I {} ls -a -l {}',
#  'find Path -name Regex -ctime +Timespan -exec rm -f {} \\;',
#  'find Path -name Regex -type f -ls',
#  'sort -n -k File File | tac',
#  'cal | sed -e Program -e Program',
#  'chown -R Regex File',
#  'watch command',
#  'echo Regex | awk Program',
#  'su Regex -s /bin/ksh',
#  'find Path -type f ! -size Size',
#  'find Path -name Regex -prune -or -type f -print',
#  'find Path -type f | grep -E Regex',
#  "find Path -type f -mtime +Timespan -mtime -Timespan | xargs -I {} tar -c -v -f $( date '+%d%m%Y'_archive.tar ) {}",
#  'find Path -name Regex -fprint File',
#  'rsync -p -g -o -d -t File File',
#  'find Path -name Regex',
#  'find Path -type f -name Regex',
#  'find Path -path Regex',
#  'find Path -type d -mtime -Timespan -print0 | xargs -0 -I {} mv -t Directory {}',
#  'find Path -name Regex',
#  'find Path -type f -newer File',
#  'finger | sed Program',
#  'find Path -type d -mmin +Quantity -print0 | xargs -0 -I {} rmdir {}',
#  'find Path -name Regex -exec echo Regex \\;',
#  'find Path ! -perm -Permission -prune',
#  'chmod Permission File',
#  "find Path -name Regex -prune -or -type d -printf ':%p'",
#  'cal | awk -v Program -v Program Program',
#  'history -w',
#  'find Path -name Regex',
#  'sed -i $( hostname ) File',
#  'find Path -name Regex -ls',
#  'find Path Path -type f -exec md5 File {} \\; | sort',
#  'find Path -maxdepth Quantity -type d -name Regex -print0 | xargs -0 -I {} rm -r -f {}',
#  'find Path -type f -size +Size',
#  'find Path -perm -Permission',
#  'dig Regex Regex o-o.myaddr.l.google.com @8.8.8.8',
#  'ln -s File',
#  'chgrp Regex File File',
#  'ssh -i File -p Regex Regex',
#  'find Path -type l -xtype l',
#  'find Path -name Regex -type f | xargs -I {} wc -l {}',
#  'find Path -amin +Quantity -amin -Quantity',
#  'find -L Path -type l -delete',
#  'bunzip2 File File | wc -c',
#  'find Path -name Regex -type d -prune -or -name Regex -print',
#  'yes Regex | head -n Quantity | xargs -I {} echo {}',
#  'zcat Regex | awk Program | head',
#  'find Path -size +Size -size -Size',
#  'head - Quantity File | tail - Quantity | tr Regex Regex',
#  'find -L Path -type l',
#  'find Path -mindepth Quantity -name Regex',
#  'find Path -type f -exec chmod Permission {} +',
#  'find Path -type l',
#  'find Path -type d -exec mkdir -p -- Directory \\;',
#  'find Path -name Regex',
#  'kill - Regex $( cat File )',
#  'find Path -name Regex | tail - Quantity | xargs -I {} rm {}',
#  'find Path -iname Regex | xargs -I {} sed -i Program {}',
#  'find Path -ctime +Timespan -type f -exec rm -f {} \\;',
#  'find Path -type f -mtime -Timespan',
#  'find Path -name Regex -print0 | xargs -0 -I {} tar -r -f File {}',
#  'find Path -regex Regex',
#  'find Path -name Regex -exec rm -r -f {} \\;',
#  'ssh -i File Regex',
#  'find Path -type d -exec basename {} \\; | wc -l',
#  'find Path -type d | sed -r Program',
#  'find Path -type f -maxdepth Quantity -exec sed -i Program {} \\;',
#  'find Path -printf "././%f\\n" | cpio -o -F Regex',
#  'set Regex',
#  'find Path -name Regex -print | xargs -I {} sed -i Program {}',
#  'find Path -type d | ssh Regex xargs -I {} mkdir -p Directory',
#  'find Path -name Regex -exec rm -r -f {} \\;',
#  'md5sum $( which Regex )',
#  'find Path -amin -Quantity',
#  'env $( cat File ) Program',
#  'find Path -size +Size',
#  'crontab File',
#  'find Path -uid Regex',
#  'find Path -size +Size',
#  'find Path Path',
#  'mkdir Directory',
#  'find Path -size -Size -exec rm {} \\;',
#  'chown -R Regex File',
#  'ln -s -F File Regex',
#  'find Path -mtime +Timespan -mtime -Timespan | head',
#  'find Path -path Regex -print',
#  'tar File File | split -b Size File Regex',
#  'ssh Regex',
#  'rmdir $( dirname Regex )',
#  'find Path -name Regex -exec du -k {} \\; | awk Program',
#  'find Path -mindepth Quantity -maxdepth Quantity -type d',
#  'df File | awk Program',
#  'read -p $( pwd -P ) Regex',
#  'find Path -perm Permission',
#  'find Path -not -path Regex -type f \\( ! -iname Regex \\)',
#  'sort -n -r -k File File',
#  'rm --force File',
#  'ssh -t Regex command',
#  'find Path -name Regex -type f -exec chmod Permission {} \\;',
#  'find Path -type d | sed Program | tr Regex Regex | sed Program',
#  'scp -P Regex File File',
#  'find Path -type f -exec chmod Permission {} \\;',
#  'find Path -name Regex -type f -printf \'"%p"\\n\' | xargs -I {} rm -f {}',
#  'find Path -mtime -Timespan',
#  'chmod Permission File File File',
#  'echo Regex $( ls -1 File | wc -l )',
#  'find Path -regextype posix-egrep -type d -regex Regex',
#  'find Path -type d',
#  'df File -B Size | tail - Quantity | awk Program | grep Regex',
#  'find Path -name Regex',
#  'find Path -mtime +Timespan -mtime -Timespan',
#  'hostname',
#  'find Path -print0 | xargs -0 -I {} mv -t Directory {}',
#  'find Path -mtime Timespan -daystart -exec cp -a {} File File \\;',
#  'find Path -type f -size +Size -exec ls -l -h {} \\; | awk Program',
#  'find Path -name Regex -mtime +Timespan',
#  'find Path -name Regex',
#  'find Path -print | grep Regex',
#  'tree --help',
#  'find Path -type f -print0 | xargs -0 -I {} grep Regex {}',
#  'find Path -type f -name Regex -exec grep -l Regex {} \\;',
#  'find Path -name Regex -exec grep -i -l Regex {} \\;',
#  'find Path -name Regex -not -path Regex -not -path Regex',
#  'finger -l | awk Program',
#  'echo Regex | od -c',
#  'find Path -maxdepth Quantity',
#  'find Path -type f -print0 | xargs -0 -I {} chown Regex {}',
#  'find Path -name Regex -type f',
#  'mkdir Directory',
#  'chown -R $( whoami ) File',
#  'chown -R Regex File File File File File',
#  'find Path -name Regex',
#  'diff -q File File',
#  'rsync --exclude Regex --exclude Regex File File',
#  'find Path -type f -newermt Regex ! -newermt Regex',
#  'find Path -type f -name Regex -exec sed -i -e Program {} \\;',
#  'find Path -type d -exec chmod Permission {} +',
#  'mkdir Directory Directory',
#  'tree | md5sum',
#  'chgrp -R Regex File',
#  'ssh-keygen -f File -N Regex',
#  'find Path -exec chown Regex {} \\;',
#  'find Path -name Regex -prune -or \\( -type f -print0 \\)',
#  'mktemp -u -t Regex',
#  'find Path -type f -atime -Timespan',
#  'find Path -type f ! -name Regex -mtime -Timespan | grep -E -v -f Regex',
#  'find Path -type f -iname Regex -or -iname Regex ! -path Regex',
#  'find Path -atime Timespan',
#  'find Path -name Regex -delete',
#  'find Path -amin +Quantity -amin -Quantity',
#  'tr -c -d Regex',
#  'find Path | cpio -p -d -u -m -v Regex',
#  'find Path -type f -newer File',
#  'find Path -mmin -Quantity | xargs -r -I {} ls -l -d {}',
#  'echo Regex | rev | cut -d Regex -f Number',
#  'mv File File',
#  "find Path -type f -printf '%T@ %p\\n' | sort -n | tail - Quantity | cut -f Number -d Regex",
#  'find Path -type f -name Regex | xargs -I {} zcat {} | wc -l',
#  'find Path -size +Size -size -Size -print',
#  'find Path -mindepth Quantity -type d ! -path Regex -name Regex -print',
#  'find Path -type f -perm Permission | xargs -I {} file {} | grep Regex | cut -d Regex -f Number',
#  'mv File File',
#  'ln -s -f File Regex',
#  'find Path -type f \\( -name Regex -or -name Regex \\) -print0 | xargs -0 -I {} ls -t {} | tail - Quantity | xargs -I {} rm {}',
#  'find Path -wholename Regex -prune -or -print',
#  'find Path -type f -mmin -Quantity -print0 | xargs -r -0 -I {} ls -l {}',
#  'grep -v Regex File',
#  'find Path -type f -name Regex -exec ls -l {} \\;',
#  'find Path -name Regex -maxdepth Quantity -exec mv -t Directory {} +',
#  'find Path -name Regex | sed -n Program | xargs -L Quantity -I {} echo Regex {}',
#  'find Path -perm Permission | xargs -I {} chmod Permission File',
#  'gzip -d -c Regex | tar -x -v -f File',
#  'find Path -mtime -Timespan',
#  'find Path -print -or -name Regex -prune',
#  'mount',
#  'find Path -samefile Regex',
#  'find Path -name Regex',
#  'find Path -user Regex',
#  'ifconfig Regex | grep -E -o Regex | grep -E -o Regex | grep -v Regex',
#  'find Path -name Regex -prune -or -type f -print',
#  'find Path -type f -not -name Regex | xargs -I {} rm {}',
#  'find Path -mtime +Timespan -delete',
#  'find Path -type d -size +Size',
#  'mount Regex -t tmpfs Regex',
#  'find Path -exec grep Regex {} +',
#  'find Path Path Path -type f | xargs -I {} chmod Permission {}',
#  'column -s Regex -t',
#  'od -c File | head - Quantity',
#  'find Path -type d -iname Regex',
#  'find Path -iname Regex | sort -r',
#  'find Path -name Regex',
#  'find Path -type f -maxdepth Quantity -empty -print0 | xargs -0 -I {} rm {}',
#  'find Path -type d -print',
#  'find Path -maxdepth Quantity -type f -empty -delete',
#  'find Path -type f -delete',
#  'find Path -name Regex -exec rename Regex {} \\;',
#  'chown Regex File',
#  ...]

# %%
utility_dist = collections.defaultdict(int)
for cmd in txt:
    ut = cmd.split(' ')[0]
    utility_dist[ut] += 1

utilities = []
scale = utility_dist['find']
ut_scale = []
for ut in utility_dist:
    utilities.append(ut)
    ut_scale.append((ut, float(utility_dist[ut]) / scale))

scale_d = {}
for ut, s in ut_scale:
    scale_d[ut] = s
scale_d
# Out:
# {'find': 1.0,
#  'date': 0.0025299662156950467,
#  'fold': 0.0001388396093978989,
#  'who': 0.014932971321907348,
#  'ls': 0.5014886691452108,
#  'df': 0.008623482405936165,
#  'chown': 0.008623482405936165,
#  'watch': 0.007003686962960678,
#  'ln': 0.012572697962143067,
#  'seq': 0.0001388396093978989,
#  'cut': 0.0018357681687055521,
#  'head': 0.00029310584206223097,
#  'mv': 0.007003686962960678,
#  'sort': 0.056353454792280516,
#  'readlink': 0.0025299662156950467,
#  'mkdir': 0.00029310584206223097,
#  'w': 0.0012804097311139564,
#  'file': 0.06261666383845241,
#  'sed': 0.007003686962960678,
#  'tac': 0.00029310584206223097,
#  'echo': 0.00029310584206223097,
#  'cat': 0.004396587630933465,
#  'od': 0.014932971321907348,
#  'rmdir': 0.00029310584206223097,
#  'dirname': 4.627986979929963e-05,
#  'ps': 0.15239961124909368,
#  'comm': 0.0025299662156950467,
#  'grep': 0.32124400290020516,
#  'join': 0.0018357681687055521,
#  'hostname': 0.004396587630933465,
#  'du': 0.045107446431050705,
#  'mktemp': 0.0012804097311139564,
#  'chmod': 0.0018357681687055521,
#  'tr': 0.0005245051910587291,
#  'su': 0.0018357681687055521,
#  'split': 0.012572697962143067,
#  'tail': 0.004396587630933465,
#  'nl': 0.0018357681687055521,
#  'env': 0.0018357681687055521,
#  'man': 0.10095182265553893,
#  'paste': 0.0001388396093978989,
#  'chgrp': 0.007003686962960678,
#  'cal': 0.008623482405936165,
#  'diff': 0.1903645311077858,
#  'tar': 8.16677722413341,
#  'rm': 0.003378430495348873,
#  'cp': 0.06932724495935084,
#  'touch': 0.0025299662156950467,
#  'md5sum': 0.004396587630933465,
#  'column': 0.040093793869459916,
#  'wc': 0.0012804097311139564,
#  'uname': 0.003378430495348873,
#  'rename': 0.0018357681687055521,
#  'more': 0.003378430495348873,
#  'bash': 0.36136865001619795,
#  'curl': 27.376533020687102,
#  'pwd': 0.0001388396093978989,
#  'tee': 0.00029310584206223097,
#  'xargs': 0.02374157320704071,
#  'wget': 12.631380837048578,
#  'shred': 0.0025299662156950467,
#  'uniq': 0.003378430495348873}

# %% [markdown]
# ## Scraping

# %%
ws = WebScraper(utilities=utilities)
ws.extract_utilities()
ws.save_json('test_syntax.json', 'test_map.json')
# Out:
# find
# syntax not found for find
# /Users/mgeorgaklis/Desktop/Fall 2021 Coursework/CS 3860/bash_gen/scraper.py:37: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 37 of the file /Users/mgeorgaklis/Desktop/Fall 2021 Coursework/CS 3860/bash_gen/scraper.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   soup = BeautifulSoup(r.text)
# date
# No web page found for zcat
# fold
# No web page found for cd
# No web page found for set
# No web page found for read
# No web page found for tree
# kill
# syntax not found for kill
# who
# ls
# df
# No web page found for history
# chown
# watch
# ln
# seq
# cut
# head
# mv
# sort
# No web page found for shopt
# No web page found for pushd
# readlink
# mkdir
# w
# rsync
# syntax not found for rsync
# No web page found for which
# file
# syntax not found for file
# sed
# tac
# echo
# crontab
# syntax not found for crontab
# ssh
# syntax not found for ssh
# No web page found for ifconfig
# No web page found for awk
# cat
# od
# false
# syntax not found for false
# rmdir
# dirname
# No web page found for dig
# ps
# comm
# No web page found for jobs
# grep
# No web page found for source
# join
# hostname
# syntax not found for hostname
# du
# No web page found for gzip
# mktemp
# chmod
# basename
# syntax not found for basename
# tr
# su
# split
# No web page found for ping
# tail
# No web page found for $(
# No web page found for finger
# nl
# env
# No web page found for mount
# ssh-keygen
# syntax not found for ssh-keygen
# pstree
# syntax not found for pstree
# yes
# syntax not found for yes
# man
# No web page found for gunzip
# paste
# chgrp
# cal
# diff
# No web page found for bind
# tar
# syntax not found for tar
# rm
# cp
# touch
# scp
# syntax not found for scp
# No web page found for bzip2
# No web page found for bunzip2
# md5sum
# column
# wc
# No web page found for bg
# uname
# rename
# tmux
# syntax not found for tmux
# groups
# No web page found for
# true
# syntax not found for true
# more
# apropos
# syntax not found for apropos
# rev
# bash
# curl
# No web page found for cpio
# pwd
# No web page found for vim
# whoami
# tee
# No web page found for fg
# xargs
# wget
# sleep
# syntax not found for sleep
# No web page found for info
# less
# syntax not found for less
# top
# syntax not found for top
# shred
# No web page found for zless
# No web page found for md5
# uniq
# gcc
# syntax not found for gcc
# No web page found for popd
# clear
# syntax not found for clear
# No web page found for compress
# nohup
# syntax not found for nohup

# %% [markdown]
# # Generating
#
# Since we currently don't know the number of valid commands, we will generate the maximum number of commands, run them all through the validator, and then process and sample accordingly.

# %%
g = Generator('test_syntax.json', 'test_map.json', utilities)

# %%
g.generate_all_commands('test_unverified.txt')
# Out:
# ['find Folder -o -cmin Number -size Number',
#  'find Folder -name Regex -regex Regex -okdir',
#  'find Folder -mtime Number -newer Number -help',
#  'find Folder -iwholename Regex -mtime Number -n',
#  'find Folder -print -nouser -help',
#  'find Folder -ok -false',
#  'find Folder -execdir -n -fprintf',
#  'find Folder -P -daystart -noignore_readdir_race',
#  'find Folder -delete -anewer Number -ok',
#  'find Folder -inum Number -samefile File -xdev',
#  'find Folder -execdir -iregex Regex -path Regex',
#  'find Folder -delete -mount -uid',
#  'find Folder -used Number -fprint0 File -xdev',
#  'find Folder -inum Number -Olevel -group Number',
#  'find Folder -mmin Number -uid -path Regex',
#  'find Folder -ls -noignore_readdir_race -size Number',
#  'find Folder -depth -used Number -ilname Regex',
#  'find Folder -version -lname Regex -empty',
#  'find Folder -or -executable -fprint0 File',
#  'find Folder -o -noignore_readdir_race -used Number',
#  'find Folder -version -depth -samefile File',
#  'find Folder -ipath Regex -mtime Number -O',
#  'find Folder -writable -O -user Number',
#  'find Folder -ok -ilname Regex -context Regex',
#  'find Folder -or -newer Number -xdev',
#  'find Folder -readable -inum Number -group Number',
#  'find Folder -H -fprint0 File -fprint File',
#  'find Folder -H -readable -ipath Regex',
#  'find Folder -fls File -cmin Number -true',
#  'find Folder -d -newer Number -print0',
#  'find Folder -iname Regex -Olevel -gid',
#  'find Folder -print -nouser -samefile File',
#  'find Folder -exec -lname Regex -n',
#  'find Folder -newerXY Number -gid -atime Number',
#  'find Folder -H -iname Regex -mmin Number',
#  'find Folder -o -writable -okdir',
#  'find Folder -newerXY Number -fls File -cnewer Number',
#  'find Folder -ls -ok -mmin Number',
#  'find Folder -execdir -lname Regex -false',
#  'find Folder -o -amin Number -context Regex',
#  'find Folder -execdir -readable -user Number',
#  'find Folder -ls -fprint0 File -amin Number',
#  'find Folder -version -inum Number -wholename Regex',
#  'find Folder -P -O -false',
#  'find Folder -ignore_readdir_race -false',
#  'find Folder -ok -warn -okdir',
#  'find Folder -nogroup -executable -fprint0 File',
#  'find Folder -name Regex -ctime Number -atime Number',
#  'find Folder -fls File -anewer Number -fprintf',
#  'find Folder -mtime Number -delete -print0',
#  'find Folder -gid -executable -amin Number',
#  'find Folder -cnewer Number -print0',
#  'find Folder -ignore_readdir_race -ilname Regex -size Number',
#  'find Folder -newerXY Number -noleaf -help',
#  'find Folder -iregex Regex -inum Number -ctime Number',
#  'find Folder -iwholename Regex -L -inum Number',
#  'find Folder -Olevel -gid -context Regex',
#  'find Folder -cnewer Number -mount -O',
#  'find Folder -print -empty -executable',
#  'find Folder -print -quit -mmin Number',
#  'find Folder -depth -exec -gid',
#  'find Folder -version -depth -ilname Regex',
#  'find Folder -group Number -user Number -path Regex',
#  'find Folder -group Number -ilname Regex',
#  'find Folder -name Regex -wholename Regex -uid',
#  'find Folder -P -daystart -gid',
#  'find Folder -H -ipath Regex -iregex Regex',
#  'find Folder -fls File -daystart -ignore_readdir_race',
#  'find Folder -ipath Regex -exec -noignore_readdir_race',
#  'find Folder -fls File -ctime Number -cnewer Number',
#  'find Folder -o -nogroup -noignore_readdir_race',
#  'find Folder -o -depth',
#  'find Folder -iregex Regex -warn -fprint0 File',
#  'find Folder -fprintf -user Number -fprint File',
#  'find Folder -ilname Regex -path Regex -xdev',
#  'find Folder -H -n -size Number',
#  'find Folder -mtime Number -samefile File -false',
#  'find Folder -nouser -fls File -prune',
#  'find Folder -L -version -P',
#  'find Folder -name Regex -cnewer Number -follow',
#  'find Folder -newerXY Number -n -mmin Number',
#  'find Folder -print -newerXY Number -fprintf',
#  'find Folder -readable -ilname Regex -fprint0 File',
#  'find Folder -ok -user Number',
#  'find Folder -execdir -H -exec',
#  'find Folder -name Regex -atime Number -true',
#  'find Folder -or -ctime Number -follow',
#  'find Folder -iregex Regex -warn -executable',
#  'find Folder -ipath Regex -noignore_readdir_race -used Number',
#  'find Folder -delete -regex Regex -fprint File',
#  'find Folder -mount -O -executable',
#  'find Folder -links Number -prune -O',
#  'find Folder -o -mtime Number -xdev',
#  'find Folder -inum Number -regex Regex -false',
#  'find Folder -prune -delete -daystart',
#  'find Folder -writable -execdir -amin Number',
#  'find Folder -iwholename Regex -exec -empty',
#  'find Folder -d -fprintf -follow',
#  'find Folder -samefile File -O -path Regex',
#  'find Folder -or -okdir -size Number',
#  'find Folder -readable -mtime Number -lname Regex',
#  'find Folder -anewer Number -cnewer Number -atime Number',
#  'find Folder -iwholename Regex -depth -ctime Number',
#  'find Folder -ls -writable -ok',
#  'find Folder -ipath Regex -noleaf -okdir',
#  'find Folder -links Number -samefile File -size Number',
#  'find Folder -iregex Regex -regex Regex -path Regex',
#  'find Folder -o -wholename Regex -anewer Number',
#  'find Folder -wholename Regex -help -O',
#  'find Folder -wholename Regex -newer Number -user Number',
#  'find Folder -depth -exec -regex Regex',
#  'find Folder -iregex Regex -O -cmin Number',
#  'find Folder -cnewer Number -O -fprint File',
#  'find Folder -iwholename Regex -inum Number -used Number',
#  'find Folder -print -inum Number -newer Number',
#  'find Folder -writable -fls File -context Regex',
#  'find Folder -used Number -samefile File -false',
#  'find Folder -okdir -executable',
#  'find Folder -readable -P -size Number',
#  'find Folder -o -ok -amin Number',
#  'find Folder -links Number -mmin Number -gid',
#  'find Folder -fls File -mount -path Regex',
#  'find Folder -ignore_readdir_race -executable -fprint0 File',
#  'find Folder -fprintf -user Number',
#  'find Folder -H -warn -O',
#  'find Folder -quit -H -newerXY Number',
#  'find Folder -mtime Number -inum Number -context Regex',
#  'find Folder -lname Regex -noleaf -true',
#  'find Folder -readable -fprint0 File -path Regex',
#  'find Folder -ctime Number -warn -cmin Number',
#  'find Folder -H -delete -ok',
#  'find Folder -wholename Regex -anewer Number -noleaf',
#  'find Folder -daystart -amin Number',
#  'find Folder -or -readable -iname Regex',
#  'find Folder -links Number -user Number -path Regex',
#  'find Folder -iname Regex -ignore_readdir_race -empty',
#  'find Folder -exec -user Number -size Number',
#  'find Folder -warn -gid -okdir',
#  'find Folder -quit -readable -Olevel',
#  'find Folder -o -iwholename Regex -H',
#  'find Folder -writable -warn -okdir',
#  'find Folder -ctime Number -wholename Regex -help',
#  'find Folder -version -help -xdev',
#  'find Folder -iname Regex -P -mmin Number',
#  'find Folder -or -d -help',
#  'find Folder -mtime Number -noignore_readdir_race -samefile File',
#  'find Folder -ls -name Regex -iwholename Regex',
#  'find Folder -execdir -gid -amin Number',
#  'find Folder -lname Regex -help -context Regex',
#  'find Folder -iname Regex -daystart -uid',
#  'find Folder -fls File -gid -cmin Number',
#  'find Folder -print -or -ctime Number',
#  'find Folder -ls -iwholename Regex -newer Number',
#  'find Folder -files0-from File -daystart -mount',
#  'find Folder -H -inum Number -delete',
#  'find Folder -ipath Regex -files0-from File -noignore_readdir_race',
#  'find Folder -ignore_readdir_race -atime Number -size Number',
#  'find Folder -nouser -P -ok',
#  'find Folder -exec -noleaf -fprint File',
#  'find Folder -noleaf -used Number -follow',
#  'find Folder -execdir -links Number -ignore_readdir_race',
#  'find Folder -or -iregex Regex -uid',
#  'find Folder -Olevel -warn -amin Number',
#  'find Folder -readable -mmin Number -empty',
#  'find Folder -print -executable -follow',
#  'find Folder -nogroup -lname Regex -help',
#  'find Folder -ls -readable -xdev',
#  'find Folder -H -L -follow',
#  'find Folder -files0-from File -iname Regex -xdev',
#  'find Folder -nogroup -anewer Number -follow',
#  'find Folder -print -O',
#  'find Folder -version -exec -executable',
#  'find Folder -fls File -noleaf -Olevel',
#  'find Folder -L -prune -true',
#  'find Folder -iwholename Regex -lname Regex -okdir',
#  'find Folder -L -links Number -ctime Number',
#  'find Folder -readable -d -ignore_readdir_race',
#  'find Folder -or -n',
#  'find Folder -noleaf -false -follow',
#  'find Folder -quit -files0-from File -d',
#  'find Folder -name Regex -links Number -fprintf',
#  'find Folder -H -noignore_readdir_race -print0',
#  'find Folder -fls File -daystart -xdev',
#  'find Folder -readable -files0-from File -xdev',
#  'find Folder -delete -daystart -O',
#  'find Folder -noleaf -gid -ilname Regex',
#  'find Folder -name Regex -fprintf -cmin Number',
#  'find Folder -iwholename Regex -mmin Number -group Number',
#  'find Folder -L -depth -delete',
#  'find Folder -lname Regex -noleaf -executable',
#  'find Folder -empty -O -fprint File',
#  'find Folder -prune -atime Number -user Number',
#  'find Folder -fls File -mount -user Number',
#  'find Folder -depth -lname Regex -gid',
#  'find Folder -d -okdir -size Number',
#  'find Folder -ls -newer Number -context Regex',
#  'find Folder -noignore_readdir_race -ignore_readdir_race -user Number',
#  'find Folder -inum Number -used Number -group Number',
#  'find Folder -cnewer Number -warn -cmin Number',
#  'find Folder -quit -L -delete',
#  'find Folder -iname Regex -wholename Regex -help',
#  'find Folder -newerXY Number -O -user Number',
#  'find Folder -inum Number -print0 -context Regex',
#  'find Folder -L -iname Regex -n',
#  'find Folder -ls -H -path Regex',
#  'find Folder -readable -atime Number -fprint File',
#  'find Folder -ls -L -context Regex',
#  'find Folder -newerXY Number -delete -ok',
#  'find Folder -links Number -mmin Number -executable',
#  'find Folder -links Number -ilname Regex -amin Number',
#  'find Folder -prune -files0-from File',
#  'find Folder -delete -amin Number -xdev',
#  'find Folder -iname Regex -regex Regex -warn',
#  'find Folder -newerXY Number -wholename Regex -empty',
#  'find Folder -print -noleaf -mmin Number',
#  'find Folder -version -mount -fprint0 File',
#  'find Folder -o -ok -fprint File',
#  'find Folder -print -readable -ilname Regex',
#  'find Folder -iwholename Regex -newerXY Number',
#  'find Folder -files0-from File -samefile File -user Number',
#  'find Folder -warn -user Number -print0',
#  'find Folder -P -anewer Number -xdev',
#  'find Folder -name Regex -print -O',
#  'find Folder -o -ipath Regex -newerXY Number',
#  'find Folder -depth -noleaf -samefile File',
#  'find Folder -exec -noleaf -cnewer Number',
#  'find Folder -iregex Regex -regex Regex -follow',
#  'find Folder -o -uid -amin Number',
#  'find Folder -ipath Regex -daystart -lname Regex',
#  'find Folder -nouser -execdir -false',
#  'find Folder -daystart -samefile File -atime Number',
#  'find Folder -name Regex -gid -fprint File',
#  'find Folder -iwholename Regex -L -false',
#  'find Folder -execdir -or -links Number',
#  'find Folder -okdir -true -amin Number',
#  'find Folder -prune -d -atime Number',
#  'find Folder -d -used Number -uid',
#  'find Folder -regex Regex -used Number -follow',
#  'find Folder -L -readable -prune',
#  'find Folder -ipath Regex -warn',
#  'find Folder -fls File -noleaf -executable',
#  'find Folder -iwholename Regex -user Number -follow',
#  'find Folder -n -ignore_readdir_race -print0',
#  'find Folder -anewer Number -newer Number -user Number',
#  'find Folder -o -mount -size Number',
#  'find Folder -nogroup -version -atime Number',
#  'find Folder -version -daystart -fprintf',
#  'find Folder -H -mount -O',
#  'find Folder -noignore_readdir_race -help -ilname Regex',
#  'find Folder -print -ignore_readdir_race -fprint0 File',
#  'find Folder -writable -or -n',
#  'find Folder -nogroup -help -empty',
#  'find Folder -readable -d -noleaf',
#  'find Folder -iregex Regex -files0-from File -used Number',
#  'find Folder -inum Number -prune -empty',
#  'find Folder -warn -mount -okdir',
#  'find Folder -iname Regex -atime Number -uid',
#  'find Folder -d -user Number -path Regex',
#  'find Folder -links Number -ctime Number -daystart',
#  'find Folder -P -wholename Regex -samefile File',
#  'find Folder -o -O -ilname Regex',
#  'find Folder -execdir -false -path Regex',
#  'find Folder -iwholename Regex -readable -follow',
#  'find Folder -noignore_readdir_race -lname Regex -executable',
#  'find Folder -ipath Regex -iname Regex -atime Number',
#  'find Folder -nogroup -cnewer Number -executable',
#  'find Folder -newerXY Number -cmin Number -size Number',
#  'find Folder -nogroup -fls File -exec',
#  'find Folder -files0-from File -delete -newer Number',
#  'find Folder -anewer Number -user Number -context Regex',
#  'find Folder -P -ok -path Regex',
#  'find Folder -iwholename Regex -cnewer Number -false',
#  'find Folder -daystart -okdir -xdev',
#  'find Folder -writable -files0-from File -group Number',
#  'find Folder -name Regex -fprintf -used Number',
#  'find Folder -ipath Regex -iname Regex -warn',
#  'find Folder -noleaf -fprintf -samefile File',
#  'find Folder -quit -used Number -print0',
#  'find Folder -L -user Number -print0',
#  'find Folder -nouser -nogroup -uid',
#  'find Folder -prune -empty -ilname Regex',
#  'find Folder -wholename Regex -mmin Number -true',
#  'find Folder -depth -fprint File -false',
#  'find Folder -samefile File -executable -print0',
#  'find Folder -iregex Regex -P -fprintf',
#  'find Folder -mtime Number -noignore_readdir_race -O',
#  'find Folder -mtime Number -inum Number -group Number',
#  'find Folder -daystart -fprintf -size Number',
#  'find Folder -print -execdir -noleaf',
#  'find Folder -prune -daystart -gid',
#  'find Folder -nouser -n -user Number',
#  'find Folder -Olevel -cnewer Number -size Number',
#  'find Folder -empty -size Number -path Regex',
#  'find Folder -iwholename Regex -anewer Number -ok',
#  'find Folder -depth -mount -false',
#  'find Folder -wholename Regex -fprintf -xdev',
#  'find Folder -mmin Number -samefile File -amin Number',
#  'find Folder -iname Regex -d -warn',
#  'find Folder -ctime Number -help -user Number',
#  'find Folder -okdir -false -follow',
#  'find Folder -readable -anewer Number -lname Regex',
#  'find Folder -newerXY Number -mtime Number -iname Regex',
#  'find Folder -fls File -d -gid',
#  'find Folder -P -fprint File',
#  'find Folder -writable -ipath Regex -ignore_readdir_race',
#  'find Folder -name Regex -mtime Number -depth',
#  'find Folder -o -quit -noignore_readdir_race',
#  'find Folder -o -lname Regex -path Regex',
#  'find Folder -mount -fprint0 File -xdev',
#  'find Folder -iregex Regex -P -regex Regex',
#  'find Folder -H -daystart -lname Regex',
#  'find Folder -inum Number -P -O',
#  'find Folder -depth -delete -false',
#  'find Folder -depth -iname Regex -fprint0 File',
#  'find Folder -inum Number -okdir -amin Number',
#  'find Folder -quit -empty -fprintf',
#  'find Folder -ctime Number -anewer Number -noleaf',
#  'find Folder -n -cmin Number -fprint0 File',
#  'find Folder -mtime Number -noleaf -help',
#  'find Folder -help -fprint0 File -print0',
#  'find Folder -writable -daystart -noleaf',
#  'find Folder -newerXY Number -depth -iregex Regex',
#  'find Folder -exec -ignore_readdir_race -executable',
#  'find Folder -ok -user Number -amin Number',
#  'find Folder -ls -n -print0',
#  'find Folder -nouser -ipath Regex -anewer Number',
#  'find Folder -print -path Regex',
#  'find Folder -o -executable -fprint0 File',
#  'find Folder -print -ipath Regex -fprintf',
#  'find Folder -execdir -noignore_readdir_race -amin Number',
#  'find Folder -o -noignore_readdir_race -ilname Regex',
#  'find Folder -or -iregex Regex -group Number',
#  'find Folder -ipath Regex -fprintf -print0',
#  'find Folder -links Number -wholename Regex -size Number',
#  'find Folder -prune -noignore_readdir_race -fprintf',
#  'find Folder -prune -Olevel -user Number',
#  'find Folder -iname Regex -okdir -xdev',
#  'find Folder -d -empty -print0',
#  'find Folder -newer Number -fprintf -group Number',
#  'find Folder -cnewer Number -print0 -false',
#  'find Folder -ls -depth -files0-from File',
#  'find Folder -inum Number -atime Number -user Number',
#  'find Folder -name Regex -L -lname Regex',
#  'find Folder -L -mtime Number -used Number',
#  'find Folder -ctime Number -cnewer Number -amin Number',
#  'find Folder -mtime Number -prune -user Number',
#  'find Folder -name Regex -readable -mtime Number',
#  'find Folder -anewer Number -samefile File -ilname Regex',
#  'find Folder -fprintf -amin Number -follow',
#  'find Folder -name Regex -inum Number -xdev',
#  'find Folder -ipath Regex -inum Number -prune',
#  'find Folder -version -d -n',
#  'find Folder -or -H -delete',
#  'find Folder -newerXY Number -false -amin Number',
#  'find Folder -prune -exec -cmin Number',
#  'find Folder -ls -quit -noignore_readdir_race',
#  'find Folder -execdir -ok -fprintf',
#  'find Folder -version -exec -noleaf',
#  'find Folder -writable -Olevel -cnewer Number',
#  'find Folder -prune -noleaf -cmin Number',
#  'find Folder -o -noleaf -cmin Number',
#  'find Folder -inum Number -ctime Number -lname Regex',
#  'find Folder -noleaf -regex Regex -print0',
#  'find Folder -anewer Number -cmin Number -size Number',
#  'find Folder -group Number -fprint File -follow',
#  'find Folder -iwholename Regex -newer Number -xdev',
#  'find Folder -fls File -empty -amin Number',
#  'find Folder -used Number -fprint File -path Regex',
#  'find Folder -name Regex -prune -ok',
#  'find Folder -inum Number -noignore_readdir_race -ok',
#  'find Folder -daystart -ignore_readdir_race -ilname Regex',
#  'find Folder -links Number -ctime Number -ignore_readdir_race',
#  'find Folder -H -L -mount',
#  'find Folder -print -quit -daystart',
#  'find Folder -iwholename Regex -Olevel -regex Regex',
#  'find Folder -execdir -or -cnewer Number',
#  'find Folder -daystart -regex Regex -empty',
#  'find Folder -inum Number -anewer Number -print0',
#  'find Folder -anewer Number -okdir -amin Number',
#  'find Folder -quit -d -wholename Regex',
#  'find Folder -iwholename Regex -readable -atime Number',
#  'find Folder -nogroup -prune -true',
#  'find Folder -version -P -n',
#  'find Folder -fls File -ilname Regex -false',
#  'find Folder -daystart -lname Regex -samefile File',
#  'find Folder -user Number -okdir -size Number',
#  'find Folder -execdir -readable -regex Regex',
#  'find Folder -delete -mount -true',
#  'find Folder -version -fls File -wholename Regex',
#  'find Folder -regex Regex -warn',
#  'find Folder -Olevel -warn -context Regex',
#  'find Folder -nouser -empty -cmin Number',
#  'find Folder -iregex Regex -newer Number -ilname Regex',
#  'find Folder -iregex Regex -iname Regex -group Number',
#  'find Folder -links Number -lname Regex -empty',
#  'find Folder -newerXY Number -regex Regex -empty',
#  'find Folder -H -mtime Number -newer Number',
#  'find Folder -noignore_readdir_race -n -false',
#  'find Folder -readable -mmin Number -fprint0 File',
#  'find Folder -writable -xdev',
#  'find Folder -mmin Number -true -context Regex',
#  'find Folder -or -cnewer Number -path Regex',
#  'find Folder -ctime Number -fprint0 File -fprint File',
#  'find Folder -ls -delete -cnewer Number',
#  'find Folder -version -user Number -cmin Number',
#  'find Folder -files0-from File -daystart -gid',
#  'find Folder -files0-from File -mmin Number -uid',
#  'find Folder -o -exec -daystart',
#  'find Folder -prune -executable -path Regex',
#  'find Folder -iname Regex -ok -false',
#  'find Folder -used Number -ilname Regex -xdev',
#  'find Folder -nogroup -O -gid',
#  'find Folder -print -regex Regex -xdev',
#  'find Folder -links Number -iname Regex -fprint0 File',
#  'find Folder -fls File -n -follow',
#  'find Folder -depth -noleaf -regex Regex',
#  'find Folder -quit -nogroup -executable',
#  'find Folder -newerXY Number -mmin Number -follow',
#  'find Folder -user Number -ilname Regex -true',
#  'find Folder -print -depth -exec',
#  'find Folder -iregex Regex -used Number -path Regex',
#  'find Folder -d -noleaf -gid',
#  'find Folder -mmin Number -print0 -uid',
#  'find Folder -name Regex -version -anewer Number',
#  'find Folder -L -depth -mmin Number',
#  'find Folder -depth -iregex Regex',
#  'find Folder -mount -ilname Regex -path Regex',
#  'find Folder -quit -wholename Regex -ok',
#  'find Folder -o -ok -regex Regex',
#  'find Folder -H -noignore_readdir_race -follow',
#  'find Folder -nogroup -L -newer Number',
#  'find Folder -fls File -noleaf -atime Number',
#  'find Folder -files0-from File -daystart -amin Number',
#  'find Folder -L -cmin Number -path Regex',
#  'find Folder -ignore_readdir_race -ilname Regex -fprint0 File',
#  'find Folder -o -iwholename Regex -fls File',
#  'find Folder -writable -depth -iregex Regex',
#  'find Folder -version -ok -fprintf',
#  'find Folder -newerXY Number -ok -gid',
#  'find Folder -depth -ok -regex Regex',
#  'find Folder -delete -cmin Number -amin Number',
#  'find Folder -name Regex -version -iname Regex',
#  'find Folder -writable -anewer Number -print0',
#  'find Folder -execdir -mtime Number -anewer Number',
#  'find Folder -H -newerXY Number -false',
#  'find Folder -used Number -okdir -xdev',
#  'find Folder -name Regex -iname Regex -true',
#  'find Folder -version -P -O',
#  'find Folder -readable -newerXY Number -follow',
#  'find Folder -print -exec -delete',
#  'find Folder -H -readable -okdir',
#  'find Folder -newerXY Number -n -ilname Regex',
#  'find Folder -P -fprint File -true',
#  'find Folder -quit -lname Regex -ignore_readdir_race',
#  'find Folder -ipath Regex -daystart -print0',
#  'find Folder -o -Olevel',
#  'find Folder -L -version -used Number',
#  'find Folder -ok -ignore_readdir_race -true',
#  'find Folder -fls File -regex Regex -cnewer Number',
#  'find Folder -iregex Regex -exec -fprintf',
#  'find Folder -o -gid -follow',
#  'find Folder -H -links Number -regex Regex',
#  'find Folder -L -mmin Number -atime Number',
#  'find Folder -nouser -cmin Number -size Number',
#  'find Folder -nouser -daystart -true',
#  'find Folder -nogroup -ipath Regex -user Number',
#  'find Folder -ignore_readdir_race -Olevel',
#  'find Folder -mtime Number -help -O',
#  'find Folder -nouser -H -used Number',
#  'find Folder -newerXY Number -fls File -cmin Number',
#  'find Folder -iregex Regex -n -uid',
#  'find Folder -samefile File -mount -true',
#  'find Folder -o -mmin Number -fprint File',
#  'find Folder -fls File -fprint File -context Regex',
#  'find Folder -Olevel -atime Number -follow',
#  'find Folder -version -newerXY Number -iname Regex',
#  'find Folder -L -d -anewer Number',
#  'find Folder -name Regex -ipath Regex -executable',
#  'find Folder -iregex Regex -daystart -newer Number',
#  'find Folder -name Regex -inum Number -fprint File',
#  'find Folder -readable -wholename Regex -true',
#  'find Folder -mtime Number -n -cmin Number',
#  'find Folder -executable -size Number -follow',
#  'find Folder -mtime Number -used Number -samefile File',
#  'find Folder -o -iregex Regex -fprint File',
#  'find Folder -okdir -fprint0 File -path Regex',
#  'find Folder -iwholename Regex -H -files0-from File',
#  'find Folder -ipath Regex -files0-from File',
#  'find Folder -nouser -noleaf -false',
#  'find Folder -execdir -depth -ignore_readdir_race',
#  'find Folder -exec -delete -user Number',
#  'find Folder -P -anewer Number -O',
#  'find Folder -newerXY Number -cnewer Number -group Number',
#  'find Folder -nouser -mtime Number -lname Regex',
#  'find Folder -nouser -cnewer Number -amin Number',
#  'find Folder -newer Number -executable -print0',
#  'find Folder -iwholename Regex -version -noignore_readdir_race',
#  'find Folder -o -iname Regex -false',
#  'find Folder -print -L -atime Number',
#  'find Folder -iregex Regex -okdir -follow',
#  'find Folder -inum Number -Olevel -warn',
#  'find Folder -quit -ctime Number -ignore_readdir_race',
#  'find Folder -inum Number -fprintf -mount',
#  'find Folder -iwholename Regex -Olevel -fprintf',
#  'find Folder -name Regex -exec -regex Regex',
#  'find Folder -L -used Number -executable',
#  'find Folder -okdir -true -path Regex',
#  'find Folder -links Number -ignore_readdir_race -follow',
#  'find Folder -iwholename Regex -gid -amin Number',
#  'find Folder -H -readable -lname Regex',
#  'find Folder -files0-from File -exec -n',
#  'find Folder -quit -wholename Regex -okdir',
#  'find Folder -execdir -used Number -samefile File',
#  'find Folder -print -n -ilname Regex',
#  'find Folder -depth -d -fprintf',
#  'find Folder -newerXY Number -noignore_readdir_race -false',
#  'find Folder -mmin Number -gid -user Number',
#  'find Folder -fprintf -executable -false',
#  'find Folder -quit -newer Number -xdev',
#  'find Folder -L -help -follow',
#  'find Folder -ignore_readdir_race -atime Number',
#  'find Folder -o -P -fprintf',
#  'find Folder -files0-from File -P -atime Number',
#  'find Folder -exec -cnewer Number -amin Number',
#  'find Folder -quit -mtime Number -n',
#  'find Folder -writable -empty',
#  'find Folder -execdir -version -anewer Number',
#  'find Folder -H -anewer Number -n',
#  'find Folder -version -exec -n',
#  'find Folder -writable -mmin Number -false',
#  'find Folder -n -noleaf -atime Number',
#  'find Folder -d -used Number -cmin Number',
#  'find Folder -nouser -Olevel -gid',
#  'find Folder -fls File -wholename Regex -warn',
#  'find Folder -name Regex -okdir -ilname Regex',
#  'find Folder -H -newerXY Number -Olevel',
#  'find Folder -links Number -depth -iregex Regex',
#  'find Folder -depth -inum Number -path Regex',
#  'find Folder -name Regex -newerXY Number -path Regex',
#  'find Folder -iwholename Regex -fprintf -user Number',
#  'find Folder -delete -help -used Number',
#  'find Folder -ls -iwholename Regex -ipath Regex',
#  'find Folder -name Regex -ok -O',
#  'find Folder -nouser -inum Number -false',
#  'find Folder -nogroup -inum Number',
#  'find Folder -n -regex Regex -false',
#  'find Folder -mmin Number -atime Number -false',
#  'find Folder -lname Regex -user Number -executable',
#  'find Folder -links Number -iname Regex -ctime Number',
#  'find Folder -samefile File -mount -fprint0 File',
#  'find Folder -depth -wholename Regex -ignore_readdir_race',
#  'find Folder -o -P -help',
#  'find Folder -name Regex -or -nogroup',
#  'find Folder -L -empty -okdir',
#  'find Folder -fprintf -user Number -uid',
#  'find Folder -execdir -cnewer Number -size Number',
#  'find Folder -L -mount -fprint0 File',
#  'find Folder -L -gid -true',
#  'find Folder -depth -ignore_readdir_race -cnewer Number',
#  'find Folder -name Regex -P -O',
#  'find Folder -ipath Regex -anewer Number -cmin Number',
#  'find Folder -version -anewer Number -noignore_readdir_race',
#  'find Folder -name Regex -mtime Number -d',
#  'find Folder -execdir -or -atime Number',
#  'find Folder -H -empty',
#  'find Folder -daystart -noignore_readdir_race -fprintf',
#  'find Folder -prune -samefile File -amin Number',
#  'find Folder -iwholename Regex -ipath Regex -regex Regex',
#  'find Folder -o -or -print0',
#  'find Folder -execdir -path Regex -amin Number',
#  'find Folder -d -wholename Regex -context Regex',
#  'find Folder -print -samefile File -context Regex',
#  'find Folder -newerXY Number -ctime Number -context Regex',
#  'find Folder -iregex Regex -regex Regex -xdev',
#  'find Folder -ls -nouser -gid',
#  'find Folder -or -newerXY Number -follow',
#  'find Folder -depth -exec -executable',
#  'find Folder -user Number -okdir -false',
#  'find Folder -inum Number -n -cnewer Number',
#  'find Folder -L -version -fprint File',
#  'find Folder -inum Number -Olevel -true',
#  'find Folder -H -exec -uid',
#  'find Folder -atime Number -cmin Number -fprint0 File',
#  'find Folder -H -cmin Number -size Number',
#  'find Folder -ipath Regex -anewer Number -used Number',
#  'find Folder -links Number -samefile File -atime Number',
#  'find Folder -ls -newerXY Number -inum Number',
#  'find Folder -daystart -noleaf -atime Number',
#  'find Folder -mtime Number -wholename Regex -okdir',
#  'find Folder -fls File -delete -ok',
#  'find Folder -exec -fprint0 File -follow',
#  'find Folder -H -anewer Number -mount',
#  'find Folder -P -used Number -cmin Number',
#  'find Folder -iregex Regex -newer Number -atime Number',
#  'find Folder -fls File -files0-from File -xdev',
#  'find Folder -L -ctime Number -anewer Number',
#  'find Folder -or -files0-from File -warn',
#  'find Folder -iregex Regex -d -empty',
#  'find Folder -or -daystart -okdir',
#  'find Folder -anewer Number -ok -amin Number',
#  'find Folder -prune -group Number -okdir',
#  'find Folder -writable -Olevel -regex Regex',
#  'find Folder -d -fprintf -okdir',
#  'find Folder -iregex Regex -n -noleaf',
#  'find Folder -delete -noignore_readdir_race -context Regex',
#  'find Folder -print -readable -depth',
#  'find Folder -ls -files0-from File -fprintf',
#  'find Folder -prune -ignore_readdir_race -uid',
#  'find Folder -execdir -iname Regex -n',
#  'find Folder -inum Number -wholename Regex -cnewer Number',
#  'find Folder -exec -cnewer Number -samefile File',
#  'find Folder -version -print0 -context Regex',
#  'find Folder -empty -used Number -print0',
#  'find Folder -name Regex -Olevel',
#  'find Folder -iwholename Regex -print -lname Regex',
#  'find Folder -readable -anewer Number -okdir',
#  'find Folder -ls -iname Regex -daystart',
#  'find Folder -fls File -size Number -follow',
#  'find Folder -or -ctime Number -Olevel',
#  'find Folder -print -Olevel -uid',
#  'find Folder -iname Regex -newer Number -fprint File',
#  'find Folder -iregex Regex -delete -newer Number',
#  'find Folder -P -executable -fprint0 File',
#  'find Folder -fls File -P -okdir',
#  'find Folder -ok -used Number -executable',
#  'find Folder -ls -inum Number -fprint File',
#  'find Folder -H -nogroup -false',
#  'find Folder -or -cnewer Number -fprint0 File',
#  'find Folder -anewer Number -cnewer Number -path Regex',
#  'find Folder -or -anewer Number -size Number',
#  'find Folder -samefile File -O -uid',
#  'find Folder -execdir -okdir -path Regex',
#  'find Folder -L -amin Number -xdev',
#  'find Folder -version -ok -help',
#  'find Folder -fprintf -cmin Number -size Number',
#  'find Folder -quit -P -fprint0 File',
#  'find Folder -H -ok -path Regex',
#  'find Folder -readable -newerXY Number -used Number',
#  'find Folder -newerXY Number -d -true',
#  'find Folder -ipath Regex -O -fprint File',
#  'find Folder -iname Regex -wholename Regex -cmin Number',
#  'find Folder -anewer Number -noignore_readdir_race -lname Regex',
#  'find Folder -cmin Number -print0 -amin Number',
#  'find Folder -print -mtime Number -exec',
#  'find Folder -warn -O -amin Number',
#  'find Folder -ipath Regex -daystart -false',
#  'find Folder -iname Regex -user Number -fprint0 File',
#  'find Folder -iregex Regex -regex Regex -context Regex',
#  'find Folder -nouser -empty -size Number',
#  'find Folder -anewer Number -samefile File -mount',
#  'find Folder -writable -ctime Number -fprintf',
#  'find Folder -name Regex -P -empty',
#  'find Folder -name Regex -group Number -path Regex',
#  'find Folder -anewer Number -group Number -fprint0 File',
#  'find Folder -nouser -files0-from File -warn',
#  'find Folder -newerXY Number -noleaf -context Regex',
#  'find Folder -execdir -inum Number -n',
#  'find Folder -noleaf -print0 -fprint File',
#  'find Folder -ls -writable -xdev',
#  'find Folder -execdir -ok -n',
#  'find Folder -wholename Regex -samefile File -true',
#  'find Folder -ls -empty -fprint0 File',
#  'find Folder -inum Number -empty -path Regex',
#  'find Folder -regex Regex -used Number -group Number',
#  'find Folder -name Regex -depth -group Number',
#  'find Folder -fls File -noignore_readdir_race -print0',
#  'find Folder -depth -gid -executable',
#  'find Folder -iwholename Regex -mmin Number -fprint File',
#  'find Folder -ipath Regex -atime Number -xdev',
#  'find Folder -depth -fprint0 File',
#  'find Folder -nouser -files0-from File -cmin Number',
#  'find Folder -exec -lname Regex -gid',
#  'find Folder -ipath Regex -P -true',
#  'find Folder -n -group Number -fprint File',
#  'find Folder -execdir -regex Regex',
#  'find Folder -noignore_readdir_race -fprintf -true',
#  'find Folder -L -version -okdir',
#  'find Folder -empty -samefile File -atime Number',
#  'find Folder -writable -ctime Number -path Regex',
#  'find Folder -print -depth -samefile File',
#  'find Folder -ipath Regex -iname Regex -noleaf',
#  'find Folder -prune -ctime Number -wholename Regex',
#  'find Folder -anewer Number -fprintf -fprint0 File',
#  'find Folder -nouser -delete -used Number',
#  'find Folder -readable -used Number -follow',
#  'find Folder -print -quit -context Regex',
#  'find Folder -quit -H -atime Number',
#  'find Folder -L -empty -xdev',
#  'find Folder -links Number -noignore_readdir_race -gid',
#  'find Folder -name Regex -ipath Regex -noleaf',
#  'find Folder -execdir -samefile File -user Number',
#  'find Folder -depth -gid',
#  'find Folder -o -iwholename Regex -cnewer Number',
#  'find Folder -ctime Number -group Number -fprint File',
#  'find Folder -nouser -L -fprint0 File',
#  'find Folder -fls File -user Number -executable',
#  'find Folder -o -newer Number -cnewer Number',
#  'find Folder -nogroup -ilname Regex -uid',
#  'find Folder -quit -depth -noleaf',
#  'find Folder -name Regex -Olevel -empty',
#  'find Folder -nogroup -version -cmin Number',
#  'find Folder -ls -ignore_readdir_race -context Regex',
#  'find Folder -name Regex -nouser',
#  'find Folder -H -delete -regex Regex',
#  'find Folder -o -help -group Number',
#  'find Folder -o -or -size Number',
#  'find Folder -daystart -size Number -path Regex',
#  'find Folder -anewer Number -lname Regex -n',
#  'find Folder -nouser -nogroup -context Regex',
#  'find Folder -d -okdir -fprint File',
#  'find Folder -noignore_readdir_race -used Number -ilname Regex',
#  'find Folder -ipath Regex -inum Number -fprint File',
#  'find Folder -execdir -prune -noleaf',
#  'find Folder -iwholename Regex -version -fprint File',
#  'find Folder -ctime Number -atime Number -false',
#  'find Folder -nouser -noleaf -fprintf',
#  'find Folder -links Number -executable -follow',
#  'find Folder -samefile File -fprint0 File -amin Number',
#  'find Folder -samefile File -path Regex -context Regex',
#  'find Folder -help -empty -executable',
#  'find Folder -exec -atime Number -cmin Number',
#  'find Folder -nogroup -fprintf -warn',
#  'find Folder -L -noleaf -ilname Regex',
#  'find Folder -ls -ignore_readdir_race -print0',
#  'find Folder -iregex Regex -files0-from File -xdev',
#  'find Folder -files0-from File -warn -user Number',
#  'find Folder -newerXY Number -daystart -true',
#  'find Folder -version -executable -true',
#  'find Folder -regex Regex -print0 -fprint File',
#  'find Folder -nogroup -readable -uid',
#  'find Folder -n -mount -gid',
#  'find Folder -P -Olevel -print0',
#  'find Folder -samefile File -true -follow',
#  'find Folder -group Number -false -context Regex',
#  'find Folder -writable -iname Regex -wholename Regex',
#  'find Folder -n -fprint0 File -print0',
#  'find Folder -prune -wholename Regex -delete',
#  'find Folder -mtime Number -fls File -cnewer Number',
#  'find Folder -fls File -inum Number -used Number',
#  'find Folder -wholename Regex',
#  'find Folder -print -H -lname Regex',
#  'find Folder -nouser -noignore_readdir_race -used Number',
#  'find Folder -group Number -xdev -context Regex',
#  'find Folder -ls -links Number -print0',
#  'find Folder -writable -P -help',
#  'find Folder -version -regex Regex -ilname Regex',
#  'find Folder -iname Regex -empty -used Number',
#  'find Folder -quit -anewer Number -true',
#  'find Folder -d -atime Number -follow',
#  'find Folder -P -warn -true',
#  'find Folder -ls -newerXY Number -path Regex',
#  'find Folder -mtime Number -wholename Regex -print0',
#  'find Folder -name Regex -lname Regex -help',
#  'find Folder -L -prune -n',
#  'find Folder -print -nouser -ctime Number',
#  'find Folder -writable -O -amin Number',
#  'find Folder -ipath Regex -mount -O',
#  'find Folder -delete -noignore_readdir_race -ignore_readdir_race',
#  'find Folder -links Number -newer Number -user Number',
#  'find Folder -fprintf -uid -amin Number',
#  'find Folder -depth -anewer Number -fprint File',
#  'find Folder -writable -cnewer Number -ilname Regex',
#  'find Folder -L -iregex Regex -ignore_readdir_race',
#  'find Folder -nouser -fprintf -fprint0 File',
#  'find Folder -H -used Number -samefile File',
#  'find Folder -L -ctime Number -amin Number',
#  'find Folder -noignore_readdir_race -fprintf -warn',
#  'find Folder -depth -inum Number -true',
#  'find Folder -writable -mtime Number -amin Number',
#  'find Folder -user Number -amin Number -context Regex',
#  'find Folder -iwholename Regex -quit -mount',
#  'find Folder -nouser -ignore_readdir_race -mount',
#  'find Folder -newer Number -user Number -cmin Number',
#  'find Folder -warn -mount -true',
#  'find Folder -iwholename Regex -newerXY Number -exec',
#  'find Folder -newer Number -mount -print0',
#  'find Folder -name Regex -files0-from File -size Number',
#  'find Folder -ctime Number -group Number -executable',
#  'find Folder -delete -n -print0',
#  'find Folder -help -user Number -print0',
#  'find Folder -H -noleaf -executable',
#  'find Folder -o -cnewer Number -amin Number',
#  'find Folder -version -delete -user Number',
#  'find Folder -ls -prune -ctime Number',
#  'find Folder -Olevel -executable -false',
#  'find Folder -iregex Regex -iname Regex -daystart',
#  'find Folder -ls -gid -user Number',
#  'find Folder -noignore_readdir_race -Olevel -fprint File',
#  'find Folder -print -files0-from File -gid',
#  'find Folder -nogroup -delete -true',
#  'find Folder -execdir -n -regex Regex',
#  'find Folder -n -ilname Regex -amin Number',
#  'find Folder -iwholename Regex -ctime Number -empty',
#  'find Folder -links Number -prune -help',
#  'find Folder -L -mtime Number -delete',
#  'find Folder -ipath Regex -n -user Number',
#  'find Folder -wholename Regex -lname Regex -gid',
#  'find Folder -mtime Number -noignore_readdir_race -gid',
#  'find Folder -H -delete -cnewer Number',
#  'find Folder -H -links Number -iname Regex',
#  'find Folder -o -Olevel -group Number',
#  'find Folder -links Number -user Number -cmin Number',
#  'find Folder -writable -d -daystart',
#  'find Folder -anewer Number -n -O',
#  'find Folder -nouser -d -path Regex',
#  'find Folder -daystart -newer Number',
#  'find Folder -print -iregex Regex -group Number',
#  'find Folder -ipath Regex -P -lname Regex',
#  'find Folder -prune -ignore_readdir_race -cmin Number',
#  'find Folder -cnewer Number -gid -follow',
#  'find Folder -delete -noleaf -ignore_readdir_race',
#  'find Folder -d -mmin Number -ilname Regex',
#  'find Folder -ignore_readdir_race -executable -ilname Regex',
#  'find Folder -L -mtime Number -fprint0 File',
#  'find Folder -prune -delete -ignore_readdir_race',
#  'find Folder -name Regex -ctime Number -used Number',
#  'find Folder -depth -mount -fprint File',
#  'find Folder -noignore_readdir_race -user Number -path Regex',
#  'find Folder -newerXY Number -samefile File -fprint File',
#  'find Folder -nouser -H -warn',
#  'find Folder -name Regex -depth -follow',
#  'find Folder -nouser -noignore_readdir_race -Olevel',
#  'find Folder -n -gid -amin Number',
#  'find Folder -readable -ok -regex Regex',
#  'find Folder -nouser -exec -gid',
#  'find Folder -iwholename Regex -ok -context Regex',
#  'find Folder -version -ctime Number -newer Number',
#  'find Folder -lname Regex -samefile File -follow',
#  'find Folder -iname Regex -newer Number -true',
#  'find Folder -writable -empty -user Number',
#  'find Folder -writable -depth -samefile File',
#  'find Folder -iwholename Regex -readable -lname Regex',
#  'find Folder -o -fprintf -O',
#  'find Folder -execdir -mtime Number -gid',
#  'find Folder -ls -noignore_readdir_race -okdir',
#  'find Folder -readable -delete -cnewer Number',
#  'find Folder -exec -mmin Number -xdev',
#  'find Folder -nouser -newer Number -atime Number',
#  'find Folder -fls File -empty -size Number',
#  'find Folder -H -inum Number -path Regex',
#  'find Folder -ipath Regex -warn -path Regex',
#  'find Folder -iwholename Regex -gid -fprint0 File',
#  'find Folder -ipath Regex -iregex Regex -warn',
#  'find Folder -delete -noignore_readdir_race -ilname Regex',
#  'find Folder -H -iregex Regex -n',
#  'find Folder -H -files0-from File -used Number',
#  'find Folder -depth -n -mount',
#  'find Folder -execdir -ok -noleaf',
#  'find Folder -o -execdir -Olevel',
#  'find Folder -iregex Regex -noleaf -xdev',
#  'find Folder -depth -ok -group Number',
#  'find Folder -quit -execdir -fprint File',
#  'find Folder -mtime Number -gid -path Regex',
#  'find Folder -iregex Regex -Olevel -group Number',
#  'find Folder -execdir -noignore_readdir_race',
#  'find Folder -links Number -mtime Number -cnewer Number',
#  'find Folder -files0-from File -d -wholename Regex',
#  'find Folder -print -L -ignore_readdir_race',
#  'find Folder -nouser -nogroup -amin Number',
#  'find Folder -o -ipath Regex -fprint0 File',
#  'find Folder -iregex Regex -prune -fprint File',
#  'find Folder -ipath Regex -iregex Regex -atime Number',
#  'find Folder -quit -readable -fprint0 File',
#  'find Folder -readable -files0-from File -follow',
#  'find Folder -P -noignore_readdir_race -ignore_readdir_race',
#  'find Folder -writable -depth -fprintf',
#  'find Folder -quit -mtime Number -P',
#  'find Folder -print -newer Number -regex Regex',
#  'find Folder -ls -size Number -path Regex',
#  'find Folder -or -H -newerXY Number',
#  'find Folder -warn -ilname Regex -size Number',
#  'find Folder -n -warn -cmin Number',
#  'find Folder -or -regex Regex -cmin Number',
#  'find Folder -depth -mmin Number -help',
#  'find Folder -d -user Number -size Number',
#  'find Folder -nouser -n -size Number',
#  'find Folder -nogroup -n -ilname Regex',
#  'find Folder -writable -help -uid',
#  'find Folder -noignore_readdir_race -Olevel -warn',
#  'find Folder -print -used Number -group Number',
#  'find Folder -ls -execdir -version',
#  'find Folder -iregex Regex -uid -follow',
#  'find Folder -print -inum Number -daystart',
#  'find Folder -anewer Number -mmin Number -regex Regex',
#  'find Folder -depth -noignore_readdir_race -executable',
#  'find Folder -execdir -gid -cmin Number',
#  'find Folder -prune -files0-from File -ctime Number',
#  'find Folder -writable -newer Number -fprintf',
#  'find Folder -nouser -fprintf -mount',
#  'find Folder -links Number -anewer Number -user Number',
#  'find Folder -depth -noignore_readdir_race -n',
#  'find Folder -exec -d -print0',
#  'find Folder -inum Number -warn -gid',
#  'find Folder -O -gid -cmin Number',
#  'find Folder -readable -links Number -xdev',
#  'find Folder -o -cnewer Number -fprint0 File',
#  'find Folder -gid -cmin Number -ilname Regex',
#  'find Folder -ipath Regex -d -print0',
#  'find Folder -nouser -L -xdev',
#  'find Folder -iname Regex -mount -context Regex',
#  'find Folder -inum Number -exec -ignore_readdir_race',
#  'find Folder -prune -help -print0',
#  'find Folder -nouser -ctime Number -follow',
#  'find Folder -newer Number -mount -atime Number',
#  'find Folder -nouser -noleaf -mount',
#  'find Folder -ctime Number -noleaf -O',
#  'find Folder -cnewer Number -follow',
#  'find Folder -prune -wholename Regex -anewer Number',
#  'find Folder -noignore_readdir_race -empty -fprint0 File',
#  'find Folder -o -print -noleaf',
#  'find Folder -help -samefile File -fprint0 File',
#  'find Folder -name Regex -writable -daystart',
#  'find Folder -depth -inum Number -help',
#  'find Folder -L -ipath Regex -context Regex',
#  'find Folder -iwholename Regex -mount -xdev',
#  'find Folder -writable -atime Number -fprint File',
#  'find Folder -empty -used Number -size Number',
#  'find Folder -nogroup -lname Regex -cmin Number',
#  'find Folder -name Regex -L -mtime Number',
#  'find Folder -noleaf -regex Regex -cmin Number',
#  'find Folder -H -fprint File -context Regex',
#  'find Folder -nogroup -d -size Number',
#  'find Folder -files0-from File -n -ilname Regex',
#  'find Folder -mmin Number -fprintf -follow',
#  'find Folder -depth -iname Regex -fprint File',
#  'find Folder -ls -samefile File -gid',
#  'find Folder -print -used Number -cmin Number',
#  'find Folder -or -depth',
#  'find Folder -inum Number -prune -gid',
#  'find Folder -name Regex -execdir -okdir',
#  'find Folder -mtime Number -noignore_readdir_race -fprint0 File',
#  'find Folder -name Regex -readable -uid',
#  'find Folder -inum Number -fprint File -xdev',
#  'find Folder -quit -used Number',
#  'find Folder -P -help -fprint File',
#  'find Folder -execdir -newerXY Number -links Number',
#  'find Folder -writable -mmin Number -okdir',
#  'find Folder -ctime Number -ok -print0',
#  'find Folder -wholename Regex -anewer Number -regex Regex',
#  'find Folder -version -mmin Number -fprint0 File',
#  'find Folder -d -wholename Regex -path Regex',
#  'find Folder -noignore_readdir_race -mmin Number -group Number',
#  'find Folder -links Number -cnewer Number -mount',
#  'find Folder -d -cnewer Number -okdir',
#  'find Folder -iregex Regex -ignore_readdir_race -gid',
#  'find Folder -links Number -ignore_readdir_race -path Regex',
#  'find Folder -name Regex -o -Olevel',
#  'find Folder -readable -files0-from File -mmin Number',
#  'find Folder -version -mmin Number -warn',
#  'find Folder -mtime Number -fls File -user Number',
#  'find Folder -noleaf -atime Number -okdir',
#  'find Folder -o -newerXY Number -d',
#  'find Folder -d -delete -cmin Number',
#  'find Folder -newerXY Number -links Number -fprint File',
#  'find Folder -anewer Number -empty -atime Number',
#  'find Folder -depth -noignore_readdir_race -group Number',
#  'find Folder -quit -links Number -ilname Regex',
#  'find Folder -nouser -fprintf -used Number',
#  'find Folder -ls -exec -cmin Number',
#  'find Folder -nogroup -exec -mount',
#  'find Folder -prune -samefile File -follow',
#  'find Folder -mtime Number -n -fprint File',
#  'find Folder -iwholename Regex -prune -cnewer Number',
#  'find Folder -execdir -files0-from File -fprintf',
#  'find Folder -nogroup -Olevel -user Number',
#  'find Folder -iname Regex -mmin Number -fprint0 File',
#  'find Folder -ipath Regex -n -ilname Regex',
#  'find Folder -ipath Regex -fls File',
#  'find Folder -nogroup -n -newer Number',
#  'find Folder -execdir -fls File -wholename Regex',
#  'find Folder -inum Number -noignore_readdir_race -path Regex',
#  'find Folder -nogroup -samefile File -ilname Regex',
#  'find Folder -noleaf -cnewer Number -O',
#  'find Folder -cnewer Number -fprintf -context Regex',
#  'find Folder -exec -executable -context Regex',
#  'find Folder -ls -regex Regex -help',
#  'find Folder -quit -iregex Regex -size Number',
#  'find Folder -H -fls File -used Number',
#  'find Folder -mtime Number -used Number -warn',
#  'find Folder -wholename Regex -anewer Number -cnewer Number',
#  'find Folder -ctime Number -print0',
#  'find Folder -wholename Regex -n -atime Number',
#  'find Folder -L -regex Regex -print0',
#  'find Folder -exec -delete -xdev',
#  'find Folder -mmin Number -samefile File -follow',
#  'find Folder -execdir -ignore_readdir_race -ilname Regex',
#  'find Folder -links Number -iname Regex -d',
#  'find Folder -iwholename Regex -execdir -cmin Number',
#  'find Folder -readable -prune -cnewer Number',
#  'find Folder -writable -mmin Number -amin Number',
#  'find Folder -version -iregex Regex -follow',
#  'find Folder -mtime Number -noignore_readdir_race -ilname Regex',
#  'find Folder -depth -ilname Regex -follow',
#  'find Folder -exec -Olevel -true',
#  'find Folder -name Regex -ipath Regex -ok',
#  'find Folder -wholename Regex -empty -okdir',
#  'find Folder -daystart -ok -executable',
#  'find Folder -ipath Regex -warn -atime Number',
#  'find Folder -name Regex -depth -fls File',
#  'find Folder -fprintf -path Regex',
#  ...]

# %%
replace('rep_map.json', 'test_unverified.txt', 'test_rep.txt')

# %%
with open('test_rep.txt') as fp:
    print(len(fp.read().split('\n')))
# Out:
# 3323603

# %% [markdown]
# This is way too many commands to verify, so we will make sure every utility has no more commands than half the number that find has.

# %%
with open('test_rep.txt') as fp:
    txt = fp.read().split('\n')

d = collections.defaultdict(list)
for line in txt:
    d[line.split(" ")[0]].append(line)
    
print(f"Number of find commands: {len(d['find'])}")

import random
ret_list = []

maximum = len(d['find']) // 2
for ut in d:
    if ut == 'find':
        ret_list.extend(d[ut])
    elif len(d[ut]) > maximum:
        ret_list.extend(random.sample(d[ut], maximum))

with open('short_rep.txt', 'w') as fp:
    fp.write("\n".join(ret_list))
# Out:
# Number of find commands: 64823

# %%
len(ret_list)
# Out:
# 194467

# %%
with open('verified_find_3.txt') as fp:
    txt = fp.read().split('\n')
    print(len(txt))
# Out:
# 53564

# %%
d2 = collections.defaultdict(list)
for line in txt:
    ut = line.split(" ")[0]
    if "--" not in line:
        d2[ut].append(line)
        
multiplier = len(d2['find'])
final_ret = []
for ut in d2:
    num_wanted = int(scale_d[ut] * multiplier)
    if len(d2[ut]) <= num_wanted:
        final_ret.extend(d2[ut])
    else:
        final_ret.extend(random.sample(d2[ut], num_wanted))
len(final_ret)
# Out:
# 35440

# %%
with open('new_training.txt', 'w') as fp:
    fp.write('\n'.join(final_ret))

# %%
import json
def make_generic(rep_path, in_file, out_file):
    with open(rep_path, 'r') as fp:
        reps = json.load(fp)
    
    d = {}
    for k in reps:
        d[reps[k]] = k
        
    with open(in_file) as fp:
        cmds = fp.read().split('\n')
    
    ret = []
    for cmd in cmds:
        ret_cmd = []
        lst = cmd.split(" ")
        for val in lst:
            if val in d:
                val = d[val]
            ret_cmd.append(val)
        ret.append(" ".join(ret_cmd))
    
    with open(out_file, 'w') as fp:
        fp.write("\n".join(ret))

# %%
make_generic('rep_map.json', 'new_training.txt', 'generic_training.txt')
ret = []
import json
with open('generic_training.txt') as fp:
    cmds = fp.read().split('\n')
    print(len(cmds))
    for cmd in cmds:
        cmd = cmd.replace("Folder", "Path")
        ret.append(cmd)
ret = "\n".join(ret)

with open('generic_training.txt', 'w') as fp:
    fp.write(ret)
# Out:
# 35440

# %% [markdown]
# Verifying the training data

# %%
with open('cmds_proccess_train.txt') as fp:
    txt = fp.
